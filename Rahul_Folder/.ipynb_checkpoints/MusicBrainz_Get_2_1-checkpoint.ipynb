# %%
import jsonlines
import requests
import csv
from bs4 import BeautifulSoup
import pandas as pd
import tqdm
import random
import time
import pickle
import re

# %%
with open("songkick_names_part1.p", "rb") as f:
    part_1 = pickle.load(f)

# %%
def get_text(html_object):
    if "text" in html_object:
        return html_object["text"].strip()
    else:
        return html_object.get_text().strip()

def get_link(html_object):
    if "href" in html_object.attrs:
        return html_object.attrs["href"]
    return ""

def clean_name_of_footnote(text):
    return re.sub('\[\d+\]', '', text)

# %%
search_query = """
https://musicbrainz.org/ws/2/artist?fmt=json&query=ARTIST_NAME
"""

single_query = """
https://musicbrainz.org/ws/2/release?fmt=json&artist=ARTIST_ID&type=single&limit=100&offset=OFFSET
"""

album_query = """
https://musicbrainz.org/ws/2/release?fmt=json&artist=ARTIST_ID&type=album&limit=100&offset=OFFSET
"""

# %%
single_query
# Out:
# '\nhttps://musicbrainz.org/ws/2/release?fmt=json&artist=ARTIST_ID&type=single&limit=100&offset=OFFSET\n'

# %%
dictionaries = []
s = requests.Session()
a = requests.adapters.HTTPAdapter(max_retries=5)
s.mount('http://', a)
s.mount('https://', a)
s.headers = {'User-Agent': 'LiveMusique/1.0.0 ( https://github.com/rahul-khanna )'}

for i, name_url in enumerate(tqdm.tqdm(part_1)):
    if i % 100 == 0 and i > 0:
        sleep_seconds = random.randint(1, 20)
        print("Sleeping for {}".format(sleep_seconds))
        time.sleep(sleep_seconds)
        print("done sleeping")

    name = name_url[0]
    url = name_url[1]
    dict_repr = {"name" : name, "songkick_url" : url}
    updated_search_url = search_query.replace("ARTIST_NAME", name)
    x = s.get(updated_search_url, timeout=(3.05, 18.05))
    possible_results = x.json()["artists"]
    artist_id = ""
    artist_class = ""
    for result in possible_results:
        type_of_entity = result["type"]
        if type_of_entity == "Person":
            artist_id = result["id"]
            artist_class = result["gender"]
            break
        elif type_of_entity == "Group":
            artist_id = result["id"]
            artist_class = "group"
            break

    if len(artist_id) > 0:
        dict_repr["mb_id"] = artist_id
        dict_repr["mb_class"] = artist_class
        
        offset = 0
        cont = True
        updated_single_query = single_query.replace("ARTIST_ID", artist_id)
        artist_singles = []
        while cont:
            time.sleep(2)
            updated_single_query_offset = updated_single_query.replace("OFFSET", str(offset))
            y = s.get(updated_single_query_offset, timeout=(3.05, 18.05))
            singles = y.json()["releases"]
            if len(singles):
                for single in singles:
                    single_facts = {"title" : single["title"], "id" : single["id"]}
                    if "date" in single:
                        single_facts["date"] = single["date"]
                    artist_singles.append(single_facts)
                offset = offset + 100
            else:
                cont = False
        
        if len(artist_singles):
            dict_repr["singles"] = artist_singles
        
        offset = 0
        cont = True
        updated_album_query = album_query.replace("ARTIST_ID", artist_id)
        artist_albums = []
        while cont:
            time.sleep(2)
            updated_album_query_offset = updated_album_query.replace("OFFSET", str(offset))
            y = s.get(updated_album_query_offset, timeout=(3.05, 18.05))
            albums = y.json()["releases"]
            if len(albums):
                for album in albums:
                    album_facts = {"title" : album["title"], "id" : album["id"]}
                    if "date" in album:
                        album_facts["date"] = single["date"]
                    artist_albums.append(album_facts)
                offset = offset + 100
            else:
                cont = False
        
        if len(artist_albums):
            dict_repr["albums"] = artist_albums
        
    dictionaries.append(dict_repr)
# Out:
#   0%|          | 1/2793 [00:21<16:23:33, 21.14s/it]

# %%
dictionaries[0]
# Out:
# {'name': 'The Beach Boys',
#  'songkick_url': 'https://www.songkick.com/artists/268425-beach-boys',
#  'mb_id': 'ebfc1398-8d96-47e3-82c3-f782abcdb13d',
#  'mb_class': 'group',
#  'singles': [{'title': 'Good Vibrations',
#    'id': '01d23afc-8581-46a7-ade9-1605309b1df5',
#    'date': '1966'},
#   {'title': 'Long Promised Road',
#    'id': '02f014f7-83ee-48fd-8834-12da4f8504f5',
#    'date': '1971-10-11'},
#   {'title': "Don't Go Near The Water",
#    'id': '06e8369c-b3ad-43ec-ab11-da5ba123511e',
#    'date': '1971'},
#   {'title': "Honkin' Down the Highway",
#    'id': '07777d9e-c4d8-413e-8675-e527ed682ad6',
#    'date': '1977-05-30'},
#   {'title': 'I Can Hear Music',
#    'id': '0a525565-4ce5-4747-97bf-38d81daa9705',
#    'date': '1969-03-03'},
#   {'title': 'Fun Fun Fun',
#    'id': '0ebea6f9-7517-4fc7-918a-f5adf01075c3',
#    'date': '1996-02-19'},
#   {'title': 'Good Vibrations',
#    'id': '10d259c5-eeb0-45ab-8b7c-c764a05ee8a2',
#    'date': '2006-06-27'},
#   {'title': 'Tears in the Morning',
#    'id': '139166c9-da22-4a35-96c4-60555ea9f2e0',
#    'date': '1970'},
#   {'title': 'Here Comes the Night',
#    'id': '17c79195-a87a-4773-8bcf-600d25b58ea6',
#    'date': '1979-02-19'},
#   {'title': "I Just Wasn't Made For These Times",
#    'id': '184e4ce0-2718-4fae-a66d-29861afb8fdc',
#    'date': '1996-06-04'},
#   {'title': "Isn't It Time",
#    'id': '1b31af9c-de92-4006-9cb2-692e1fc3eced',
#    'date': '2012-11-28'},
#   {'title': 'Bluebirds Over the Mountain / Never Learn Not to Love',
#    'id': '1dbccddb-d034-43c6-8f77-9d49a952056b',
#    'date': '1968'},
#   {'title': 'Surfer Girl',
#    'id': '25ca4fae-6b1c-4e2c-8b96-80c21be5a714',
#    'date': '1963-07-22'},
#   {'title': 'Kokomo',
#    'id': '27300583-b681-4177-98cc-7334b270c828',
#    'date': '1988'},
#   {'title': 'Kokomo',
#    'id': '2d9fbebc-a3d3-4e42-a63b-3e34d017b604',
#    'date': '1988'},
#   {'title': 'The Greatest Single Of All Time',
#    'id': '2ee69a80-9d75-4d83-8892-72b4570488b8',
#    'date': '1997-08'},
#   {'title': "Keepin' The Summer Alive",
#    'id': '32020971-6755-4eb4-95df-d2b0317952fd',
#    'date': '1980'},
#   {'title': 'Cool, Cool Water',
#    'id': '34d8ed7f-b42a-41cf-9916-e9ba97bc3e2d',
#    'date': '1971-03-01'},
#   {'title': "Still Cruisin'",
#    'id': '36ab5c16-333c-4f81-ab19-df309dc25cbb',
#    'date': '1989'},
#   {'title': "Wouldn't It Be Nice",
#    'id': '3f25df8e-a304-4927-826e-6f3446abd8f5',
#    'date': '1966-08-01'},
#   {'title': "Good Timin'",
#    'id': '43b10da6-8506-4969-a3e4-b37b3b6b3d02',
#    'date': '1979-04-17'},
#   {'title': 'Hot Fun in the Summertime',
#    'id': '465a9132-6cfc-4186-af91-bf5c01d8d014',
#    'date': '1992-07-14'},
#   {'title': 'California Girls',
#    'id': '4709b96f-d5d5-4d1c-9e43-d1267df626cb',
#    'date': '1965-07-12'},
#   {'title': "Everyone's in Love with You",
#    'id': '4c90079c-ed49-4375-ba8a-f474f689bcb6',
#    'date': '1976-11-08'},
#   {'title': 'Tears in the Morning',
#    'id': '4f136aba-a943-40fc-b6bc-6e25185b4460',
#    'date': '1970-10-12'},
#   {'title': 'Wipeout!',
#    'id': '5386d188-a7d1-4435-b7d0-0b22ba5cf760',
#    'date': '1988'},
#   {'title': 'Be True to Your School',
#    'id': '544808dd-1dba-4d93-a58b-cdd2ce3ffda5',
#    'date': '1963-10-28'},
#   {'title': "Surfin' U.S.A. / Shut Down",
#    'id': '55eb8696-d312-47fa-a73e-c7cab931dc43',
#    'date': '1963-03-04'},
#   {'title': 'Cotton Fields / Time To Get Alone',
#    'id': '5c231673-ae04-4128-9bcb-5edb35c42075',
#    'date': '1969'},
#   {'title': 'Do It Again',
#    'id': '5c4d95a9-5992-42c1-96f1-8b788689e03d',
#    'date': '1991'},
#   {'title': "Don't Worry Baby / I Get Around",
#    'id': '5dc6b21f-c5f0-4cf2-8f07-aba6a747da89',
#    'date': '1964'},
#   {'title': 'The Little Girl I Once Knew',
#    'id': '5fccf917-7054-47ca-a5f9-ade99649a151',
#    'date': '1965-11'},
#   {'title': 'Good Vibrations / Heroes and Villains',
#    'id': '613b22a0-6cff-4392-84b5-c9a792113212',
#    'date': '2011-04-16'},
#   {'title': 'The Man With All the Toys',
#    'id': '6278dee0-d826-47a7-95da-4a13e1d48a96',
#    'date': '1964-11-09'},
#   {'title': 'The Beach Boys Medley / God Only Knows',
#    'id': '646810bf-0e34-4f61-bf78-211fb675c79e',
#    'date': '1981'},
#   {'title': 'Surfin’ U.S.A.',
#    'id': '65fa348a-e246-4f47-889f-4819a9d966d0',
#    'date': '1963-03-04'},
#   {'title': 'Sloop John B',
#    'id': '6c03b358-6432-4099-b227-753f27a2ab92',
#    'date': '1966-03'},
#   {'title': 'Barbara Ann',
#    'id': '6fcdb0e2-fbd8-4341-92e2-205d6817f627',
#    'date': '1965-12-20'},
#   {'title': 'It’s a Beautiful Day',
#    'id': '70f669f9-1faa-424a-bd18-7cd8f5658e83',
#    'date': '1979-10-18'},
#   {'title': 'God Only Knows',
#    'id': '73033617-beac-4263-9afe-167df8149279',
#    'date': '1966'},
#   {'title': "Darlin'",
#    'id': '7738b28e-d8e4-4279-b7f8-2828eb6690c9',
#    'date': '1967-12-18'},
#   {'title': 'Slip On Through',
#    'id': '77abdde6-bcca-40c1-a95b-81e5d0f8cbde',
#    'date': '1970-06-29'},
#   {'title': "Surfin' Safari",
#    'id': '77d04600-82a7-471b-a1f2-26792b38901c',
#    'date': '2012-11-23'},
#   {'title': 'Fun, Fun, Fun',
#    'id': '7a389b19-f58e-4fa2-8692-db5e7b73d1f8',
#    'date': '1964'},
#   {'title': 'Marcella',
#    'id': '7a473ca6-8f0d-4e6e-8bee-d539b769148a',
#    'date': '1972-06-26'},
#   {'title': 'Fun, Fun, Fun / Why Do Fools Fall in Love',
#    'id': '7cd2fcd7-0bdc-4aaa-8653-78212c5e270b',
#    'date': '1964'},
#   {'title': 'Ten Little Indians',
#    'id': '7cd5a523-323c-4906-b9bb-6796837bd0c4',
#    'date': '1962-11-26'},
#   {'title': 'Forever',
#    'id': '7d9c0a7c-5757-4c40-bd02-8e67fd0f2a9a',
#    'date': '1992'},
#   {'title': 'When I Grow Up (to Be a Man)',
#    'id': '7f496e3d-9b6c-4345-92c5-94fbf4ac9cfc',
#    'date': '1964'},
#   {'title': "Vega-Tables / Surf's Up",
#    'id': '7f94e676-9ad1-4714-b54f-c3b121cb4aa7',
#    'date': '2011-10-31'},
#   {'title': "Oh Darlin'",
#    'id': '81028718-8379-4f4a-a241-e3bda47e8f55',
#    'date': '1980'},
#   {'title': "Surfin'",
#    'id': '847b7d6c-e1dd-4ea6-a2e5-fed3aeea60cd',
#    'date': '1961-12-08'},
#   {'title': "Rock 'n' Roll to the Rescue",
#    'id': '862b3e0e-7975-4dc9-84d3-a64da7c4d282',
#    'date': '1986'},
#   {'title': "Livin' with a Heartache",
#    'id': '86f198a6-1c86-4b16-a97b-d1ba5437f3f9',
#    'date': '1980-05-21'},
#   {'title': 'Dance, Dance, Dance',
#    'id': '874d46b3-3a89-47a4-9bc5-1e8f586ffff0',
#    'date': '1964-11'},
#   {'title': "Sloop John B / You're So Good to Me",
#    'id': '886da14e-2d77-41b9-950d-c93c6cbca8e3',
#    'date': '1966'},
#   {'title': 'Problem Child',
#    'id': '88b581f2-a438-4f30-9656-dce1593274f2',
#    'date': '1990-07-23'},
#   {'title': "It's Gettin' Late",
#    'id': '8aee52d8-4b01-44ea-b5ec-9fc503e09396',
#    'date': '1985-07-17'},
#   {'title': 'Somewhere Near Japan',
#    'id': '8c56f52e-9e26-4456-8a48-1ebb9916a136',
#    'date': '1990-01-11'},
#   {'title': 'Disney Girls (1957)',
#    'id': '8e406055-4704-404b-8030-3215ec4a315d',
#    'date': '1973'},
#   {'title': 'Come Go With Me',
#    'id': '8ef47503-30d6-4b1e-9016-679faffd4bc6',
#    'date': '1981-11-02'},
#   {'title': 'Friends',
#    'id': '93402c6d-5415-42cc-8f38-91fe06dc709b',
#    'date': '1968-04-15'},
#   {'title': 'Long Promised Road',
#    'id': '95b33593-e102-4d5e-a988-fd6248979821',
#    'date': '1971-05-24'},
#   {'title': 'Help Me, Rhonda',
#    'id': '9e165e14-3b6e-44d3-9e79-1f646e85266b',
#    'date': '1965-04-05'},
#   {'title': "Gettin' Hungry",
#    'id': '9e79c3d9-0549-4e41-92d5-6f940d7c05d2',
#    'date': '1967-08-28'},
#   {'title': 'Heroes and Villains',
#    'id': 'a569dc75-f305-46b3-9e78-d031b1e9439f',
#    'date': '1967'},
#   {'title': 'Do It Again',
#    'id': 'a78cc672-9434-4860-8136-42d061d69e68',
#    'date': '1968-07-08'},
#   {'title': 'California Saga: California',
#    'id': 'a79974bc-05e0-45b0-a95e-96ab4db482c1',
#    'date': '1973-04-16'},
#   {'title': 'Good Vibrations',
#    'id': 'a99983da-59cf-45a2-9f1f-e6a5f8a73c26',
#    'date': '1966'},
#   {'title': 'Bluebirds Over the Mountain',
#    'id': 'b0b85882-5db6-4697-aa35-2f7d0c1e9d76',
#    'date': '1968-12-02'},
#   {'title': 'Lady Lynda',
#    'id': 'b1d0bfb7-dd7e-4ca3-9f03-dd721671bb39',
#    'date': '1979-06'},
#   {'title': 'Getcha Back',
#    'id': 'b662efc4-8e48-4aad-996e-5b94326b2ee2',
#    'date': '1985-05-08'},
#   {'title': 'Add Some Music to Your Day',
#    'id': 'b67338df-d006-43ae-8427-bbec9e8b5193',
#    'date': '1970-02-23'},
#   {'title': 'Crocodile Rock',
#    'id': 'bb0444b0-d1fa-49ae-9abf-dc336709134c',
#    'date': '1991'},
#   {'title': "That's Why God Made The Radio",
#    'id': 'bf6bf648-450a-4d36-b78a-50634055d588',
#    'date': '2012-04-26'},
#   {'title': 'Child of Winter',
#    'id': 'c1e402ec-e181-4832-9d06-dc4fec197f29',
#    'date': '1974-12-23'},
#   {'title': "Surfin' USA / Shut Down",
#    'id': 'c3d978be-d141-4e96-8e94-311679b96d80',
#    'date': '1963'},
#   {'title': 'Problem Child',
#    'id': 'c5d94dcb-22e1-4799-bb5d-3e71d8d18e82',
#    'date': '1990'},
#   {'title': 'Rock and Roll Music',
#    'id': 'c73b7de9-73eb-4a9a-96f4-c1150b5533f5',
#    'date': '1976-05-24'},
#   {'title': 'Cotton Fields',
#    'id': 'c7b01188-7ce9-47a1-8b3f-0279e0592c97',
#    'date': '1970-04-20'},
#   {'title': 'I Get Around',
#    'id': 'cba471f4-26c1-4ef8-b00c-e583dc4bfc05',
#    'date': '1964-05-11'},
#   {'title': 'Heroes and Villains',
#    'id': 'ce62f533-6bce-4f5f-bfbb-6c75b8068995',
#    'date': '1967-07'},
#   {'title': "Surf's Up",
#    'id': 'd2eff077-f84d-453b-910b-6ebe5b075c2d',
#    'date': '1971-11-29'},
#   {'title': 'Wipe Out',
#    'id': 'd379e148-0621-4823-b2f0-3ca4e35a5a49',
#    'date': '1987-07-10'},
#   {'title': 'Break Away',
#    'id': 'd4d0dc10-a9ea-49f2-95b2-1917e2d6be47',
#    'date': '1969'},
#   {'title': "Surfin' Safari",
#    'id': 'd4f5c14c-f655-42af-93f4-bfc03fcd8b16',
#    'date': '1962-06-04'},
#   {'title': "California Dreamin'",
#    'id': 'd5f156e2-0fd7-4a81-8b39-604edf6c8637',
#    'date': '1986-05'},
#   {'title': 'Wipeout',
#    'id': 'd97441e3-e6f6-423d-829a-50af30235c8a',
#    'date': '1987'},
#   {'title': 'Little Saint Nick',
#    'id': 'd9c265f4-80cf-4785-99ef-d4e679506dee',
#    'date': '1963-11-09'},
#   {'title': 'You Need a Mess of Help to Stand Alone',
#    'id': 'db27f353-b569-495b-9d50-d2069745dc6a',
#    'date': '1972'},
#   {'title': 'Wild Honey',
#    'id': 'dbf78462-d10e-4109-a8c9-71ab23693fa1',
#    'date': '1967-10-23'},
#   {'title': 'Do It Again',
#    'id': 'e277b1d8-5670-4009-996b-9ed7297e5831',
#    'date': '1968'},
#   {'title': "It's OK",
#    'id': 'e43314c2-ea55-4a6c-9c07-1f7b20f04705',
#    'date': '1976-08-30'},
#   {'title': 'Cabin Essence',
#    'id': 'e899c74f-dd4d-4ecb-9e30-cc924480ec12',
#    'date': '2011-06'},
#   {'title': 'Sail On, Sailor',
#    'id': 'eabcd95c-4c36-4555-aadd-3a431403b0d0',
#    'date': '1973-02-05'},
#   {'title': 'Good Vibrations',
#    'id': 'ecd0d3be-d50f-4aa6-9571-4204b7e075a2',
#    'date': '1966-10-10'},
#   {'title': 'Break Away',
#    'id': 'ef63c995-4d39-4ec8-9aba-ee51fcbbe825',
#    'date': '1969-06-16'},
#   {'title': 'I Can Hear Music',
#    'id': 'f1fe820d-3e5b-4964-9fdc-8bdb4a4468fd',
#    'date': '1969'},
#   {'title': 'Barbie',
#    'id': 'f82b6dae-ec81-4f15-87eb-1f0f695f9c74',
#    'date': '1962-04'},
#   {'title': 'Do You Wanna Dance',
#    'id': 'f8777fee-77a0-4660-b29f-97f073f355c8',
#    'date': '1965-02-15'}],
#  'albums': [{'title': 'Best of The Beach Boys',
#    'id': '004d28ff-3cb4-458c-8b28-21b2cbb36e78',
#    'date': '1965-02-15'},
#   {'title': 'Pet Sounds',
#    'id': '05b2f6c8-f9fd-4499-bd70-6f7d629a9cd4',
#    'date': '1965-02-15'},
#   {'title': 'The Beach Boys Best 40 Greatest Hits',
#    'id': '0a0d2f3a-1754-40d1-9375-7c2dcb6caf82',
#    'date': '1965-02-15'},
#   {'title': 'Greatest Hits',
#    'id': '0c6673da-d425-428e-8428-52aaf0cb7309',
#    'date': '1965-02-15'},
#   {'title': 'Holland / Mount Vernon and Fairway',
#    'id': '0fc50d1b-f618-4550-b39d-4be7b3c9afee',
#    'date': '1965-02-15'},
#   {'title': 'Carl and the Passions: “So Tough”',
#    'id': '0fd427a3-24b0-4de6-9266-64a806f05c36',
#    'date': '1965-02-15'},
#   {'title': 'Surf’s Up',
#    'id': '166cf57c-a26d-4a5e-9a20-e0a01496e3b4',
#    'date': '1965-02-15'},
#   {'title': 'The Beach Boys',
#    'id': '18142c2e-2456-4989-afe8-70bcd1cc69eb',
#    'date': '1965-02-15'},
#   {'title': "Surfin' Safari",
#    'id': '211a354a-27ff-4123-a42a-c1989854b606',
#    'date': '1965-02-15'},
#   {'title': 'Little Deuce Coupe',
#    'id': '22eb03d8-98ad-39da-a77c-f458395381f9',
#    'date': '1965-02-15'},
#   {'title': 'For Collectors Only (Historic Early Recordings)',
#    'id': '26487243-a959-479c-b625-b05aa531995c',
#    'date': '1965-02-15'},
#   {'title': 'Stack-o-Tracks',
#    'id': '28140693-57e7-4033-990c-2d8b367d80c9',
#    'date': '1965-02-15'},
#   {'title': 'The Beach Boys Today!',
#    'id': '2860be9f-4133-4ff0-a784-f143eaf5832d',
#    'date': '1965-02-15'},
#   {'title': 'Surfer Girl',
#    'id': '28fcd8b8-c6f7-4c77-9d31-a09af40ac294',
#    'date': '1965-02-15'},
#   {'title': 'Adult Child',
#    'id': '2bc55d41-b315-4e87-8650-e3e863ce7e2c',
#    'date': '1965-02-15'},
#   {'title': 'The Best of the Beach Boys Vol. 2',
#    'id': '2cd37121-f67f-4d65-a347-a2502ca7a340',
#    'date': '1965-02-15'},
#   {'title': 'The Very Best Of',
#    'id': '2dd131ee-7b79-4774-a247-f3dee4314fe0',
#    'date': '1965-02-15'},
#   {'title': 'The Beach Boys’ Christmas Album',
#    'id': '2e4b58c1-7218-4602-bf54-855e9ecb46b2',
#    'date': '1965-02-15'},
#   {'title': 'Good Vibrations',
#    'id': '2f0a595e-e2be-4644-971b-4b9bde1bae95',
#    'date': '1965-02-15'},
#   {'title': 'The Beach Boys Today!',
#    'id': '2f67a719-dd71-4946-a422-f03a5522b0ba',
#    'date': '1965-02-15'},
#   {'title': 'High Water',
#    'id': '318e5fb8-13cd-4a67-a887-fd751aa515ec',
#    'date': '1965-02-15'},
#   {'title': 'Concert',
#    'id': '31f2981b-5963-4dac-a4c0-3f5d5ece71d5',
#    'date': '1965-02-15'},
#   {'title': 'The Best of the Beach Boys, Volume 1',
#    'id': '32e07e6b-13c4-42e2-b88f-1109548dcc47',
#    'date': '1965-02-15'},
#   {'title': 'Endless Summer',
#    'id': '38d71472-86de-40b0-9a77-722de2083b80',
#    'date': '1965-02-15'},
#   {'title': 'Good Vibrations: The Best of the Beach Boys',
#    'id': '3c6c83ab-c552-47d0-a08c-fb43bedc21df',
#    'date': '1965-02-15'},
#   {'title': 'In Concert',
#    'id': '3dabc50b-08fb-4f89-b2e4-08a7230ee57b',
#    'date': '1965-02-15'},
#   {'title': '15 Big Ones',
#    'id': '3ef1c6d8-232d-4336-a31e-6f3e8b1cbfc2',
#    'date': '1965-02-15'},
#   {'title': 'All-Time Greatest Hits',
#    'id': '412a75f3-c233-4dc2-9c86-ff5a6edd7391',
#    'date': '1965-02-15'},
#   {'title': 'Carl And The Passions – "So Tough"',
#    'id': '43390064-3f2d-4f46-92ee-976efd3ba5e9',
#    'date': '1965-02-15'},
#   {'title': 'Pet Sounds',
#    'id': '4ac8b3ca-2139-430f-9715-a1736be1102b',
#    'date': '1965-02-15'},
#   {'title': 'Beach Boys’ Party!',
#    'id': '4c387dcb-c507-4b0e-8320-5e65ee084de9',
#    'date': '1965-02-15'},
#   {'title': 'The Beach Boys & Jan and Dean',
#    'id': '4c59cb54-8074-45e8-870a-4ea72fea1fa5',
#    'date': '1965-02-15'},
#   {'title': 'Pop History Box Set',
#    'id': '4d481ecb-c48f-434f-b38a-5c41f2158976',
#    'date': '1965-02-15'},
#   {'title': 'Pet Sounds',
#    'id': '52e75ffe-a425-41ff-b6e0-2146cc89a06f',
#    'date': '1965-02-15'},
#   {'title': '20 Grössten Hits',
#    'id': '53c24779-cfd9-4d99-9a79-84db5668e641',
#    'date': '1965-02-15'},
#   {'title': 'Shut Down, Volume 2',
#    'id': '5424c023-99a7-4b98-8235-70b5a3a583b3',
#    'date': '1965-02-15'},
#   {'title': 'Bug-In',
#    'id': '5711904d-1a91-4614-8ce1-aa324a044ef2',
#    'date': '1965-02-15'},
#   {'title': 'Surfer Girl',
#    'id': '580b036d-dfef-4753-b70e-73b255db8462',
#    'date': '1965-02-15'},
#   {'title': 'Pet Sounds',
#    'id': '58e70b2e-d73d-493a-8648-ace64d439a6b',
#    'date': '1965-02-15'},
#   {'title': 'All Summer Long',
#    'id': '5a80d7f3-11ac-499a-b5f2-231a0ed4dee7',
#    'date': '1965-02-15'},
#   {'title': 'Surfin’ USA',
#    'id': '5daacb44-12e5-42ea-9308-76fcb9a78312',
#    'date': '1965-02-15'},
#   {'title': 'Little Deuce Coupe',
#    'id': '5dc3c2c9-15a2-4cbe-ad45-e9c8eb670000',
#    'date': '1965-02-15'},
#   {'title': 'Greatest Hits',
#    'id': '5dcd10c2-d183-45ef-8d83-fc8b042e1e73',
#    'date': '1965-02-15'},
#   {'title': 'The Beach Boys’ Christmas Album',
#    'id': '5f052967-1a75-48b1-b430-89a76f4ef078',
#    'date': '1965-02-15'},
#   {'title': 'All Summer Long',
#    'id': '610ec985-10f3-3042-acb6-b90cf979008e',
#    'date': '1965-02-15'},
#   {'title': 'The Fillmore East 1971',
#    'id': '6446c4bf-35f7-4c78-b54e-01bc9662d6d7',
#    'date': '1965-02-15'},
#   {'title': 'Surfer Girl',
#    'id': '64a283a3-8eb7-4488-a99a-f52ffaaced83',
#    'date': '1965-02-15'},
#   {'title': '20/20',
#    'id': '6519e077-f4ff-49ec-bf40-696845700e7f',
#    'date': '1965-02-15'},
#   {'title': 'Smiley Smile',
#    'id': '67bb98fb-2d80-4636-9d7b-aebd5ecd455b',
#    'date': '1965-02-15'},
#   {'title': 'Beach Boys Rarities',
#    'id': '69a391e2-42d1-4ac7-bb1a-62fef71ed53b',
#    'date': '1965-02-15'},
#   {'title': 'Best of the Beach Boys, Volume 2',
#    'id': '6bd9f505-d690-431a-b968-84ed3f74f889',
#    'date': '1965-02-15'},
#   {'title': 'Shut Down, Volume 2',
#    'id': '6cfc297a-e79c-47aa-83a0-ed815330dc31',
#    'date': '1965-02-15'},
#   {'title': 'Stack-o-Tracks',
#    'id': '70538a32-f163-4896-a22f-90a1f529ca56',
#    'date': '1965-02-15'},
#   {'title': 'Sunshine Dream',
#    'id': '71b06949-ec66-4245-9474-fb4d47fb6a8b',
#    'date': '1965-02-15'},
#   {'title': 'The Very Best Of (Volume 2)',
#    'id': '75934f47-1498-4eea-a665-e590bcd9bf59',
#    'date': '1965-02-15'},
#   {'title': 'Pet Sounds',
#    'id': '7e8a98c2-5847-43dd-891a-c872a850266c',
#    'date': '1965-02-15'},
#   {'title': 'Wild Honey',
#    'id': '7f5b8bca-8d47-4fa7-b8e1-9383e6df3706',
#    'date': '1965-02-15'},
#   {'title': 'Concert',
#    'id': '873fb3a7-91eb-3afe-bd3e-39410457def5',
#    'date': '1965-02-15'},
#   {'title': 'Made in U.S.A.',
#    'id': '89030d0a-21c1-30be-b9c2-e0e3ce83af05',
#    'date': '1965-02-15'},
#   {'title': 'Surfin’ Safari',
#    'id': '8c65bbee-94c4-3671-a7a9-0c888c2f7aab',
#    'date': '1965-02-15'},
#   {'title': 'The Beach Boys',
#    'id': '902eb2bd-c333-45d1-9d1d-2152d18e1643',
#    'date': '1965-02-15'},
#   {'title': 'Beach Boys Greatest Hits: 20 All Time Greats',
#    'id': '93e3dabe-9fd3-4196-adb1-b531cdec66d9',
#    'date': '1965-02-15'},
#   {'title': 'Surfer Girl',
#    'id': '95a1c3e9-f500-4758-a640-eaf8ca27f6db',
#    'date': '1965-02-15'},
#   {'title': 'Love You',
#    'id': '9963037c-06ec-4067-8095-0a93332db3e7',
#    'date': '1965-02-15'},
#   {'title': 'Pet Sounds',
#    'id': '9ce815c5-c258-4d90-bfe0-bf3f37b0b801',
#    'date': '1965-02-15'},
#   {'title': 'Surfin’ Safari',
#    'id': '9ed6a147-d0b3-464e-bfea-38e8a6a634f5',
#    'date': '1965-02-15'},
#   {'title': 'Surfin’ USA',
#    'id': 'a034cc61-e7b0-3d86-92b5-44ef698b0045',
#    'date': '1965-02-15'},
#   {'title': 'Wild Honey',
#    'id': 'a1f4d5f1-a8c7-4e81-b98d-1e98accf63e3',
#    'date': '1965-02-15'},
#   {'title': 'Good Vibrations',
#    'id': 'a220dd2c-1e80-4527-b91f-4b29f4b63b30',
#    'date': '1965-02-15'},
#   {'title': 'Made in U.S.A.',
#    'id': 'a8a6d0c7-4e91-4e11-90f1-33bdbbe3e70b',
#    'date': '1965-02-15'},
#   {'title': 'Friends',
#    'id': 'b1b0f836-d27b-4e14-852b-12c9ca5b507c',
#    'date': '1965-02-15'},
#   {'title': 'The 15 Greatest Hits',
#    'id': 'b4c0f4ef-496f-42a1-8e30-bb5dd3d126af',
#    'date': '1965-02-15'},
#   {'title': 'The Beach Boys',
#    'id': 'b6351dee-4f75-478f-8858-3eccd91c15c9',
#    'date': '1965-02-15'},
#   {'title': 'In Concert',
#    'id': 'b7005bb9-fcd9-4d06-8c39-c5ef11275ef1',
#    'date': '1965-02-15'},
#   {'title': 'The Very Best of the Beach Boys: Anthology 1963-69',
#    'id': 'c15bd838-a4bf-4f25-a982-609a8f936ee9',
#    'date': '1965-02-15'},
#   {'title': 'Pet Sounds',
#    'id': 'c16a704b-b7a7-4614-bc38-e1c2ea405f63',
#    'date': '1965-02-15'},
#   {'title': 'Sunflower',
#    'id': 'c32d9718-6225-42fb-9dc3-c8b4db399086',
#    'date': '1965-02-15'},
#   {'title': 'Endless Summer',
#    'id': 'c6095024-d769-4cf0-8b19-f31d0a959fca',
#    'date': '1965-02-15'},
#   {'title': 'Sunflower',
#    'id': 'c63e39b6-d201-45db-bbac-99d5ee316503',
#    'date': '1965-02-15'},
#   {'title': 'Wow! Great Concert!',
#    'id': 'c65b0166-d688-42ad-9d03-6cb1f99a7961',
#    'date': '1965-02-15'},
#   {'title': "Beach Boys '69: Live in London",
#    'id': 'c65dc03f-04b9-4c48-8e9d-54474fc70475',
#    'date': '1965-02-15'},
#   {'title': 'Live in London',
#    'id': 'cd384b02-b7e4-434b-b6c4-05cec16777c2',
#    'date': '1965-02-15'},
#   {'title': 'Spirit of America',
#    'id': 'ce4c1c19-98b2-49c7-b1f8-2a2bb7633d64',
#    'date': '1965-02-15'},
#   {'title': 'Surfer Girl',
#    'id': 'd8e1be8d-2c1e-4b35-99d7-4a18cd10a559',
#    'date': '1965-02-15'},
#   {'title': 'The Beach Boys',
#    'id': 'dbd0ab8f-167f-4ac4-bf16-82b6eae35f5e',
#    'date': '1965-02-15'},
#   {'title': 'Keepin’ the Summer Alive',
#    'id': 'dd978621-e83c-40dc-98bc-1459de6f8c53',
#    'date': '1965-02-15'},
#   {'title': 'Ten Years of Harmony',
#    'id': 'e0aa4620-8bce-45ce-a66c-9415a1a76f13',
#    'date': '1965-02-15'},
#   {'title': 'The Beach Boys',
#    'id': 'e30b9ab2-8b46-488c-9d10-fb571a3ec617',
#    'date': '1965-02-15'},
#   {'title': 'M.I.U. Album',
#    'id': 'e3506339-b2fa-48ea-8933-910be791b256',
#    'date': '1965-02-15'},
#   {'title': 'L.A. (Light Album)',
#    'id': 'e3d04c48-b72e-4676-851d-8f399ff7ec21',
#    'date': '1965-02-15'},
#   {'title': 'Summer Days (And Summer Nights!!)',
#    'id': 'e56c5ab7-5432-408c-9245-f48fb77b3b71',
#    'date': '1965-02-15'},
#   {'title': 'Merry Christmas from the Beach Boys',
#    'id': 'e9ecef94-8823-4c57-b034-2767008af9cf',
#    'date': '1965-02-15'},
#   {'title': 'Summer Days (and Summer Nights!!)',
#    'id': 'ea15f628-8ab7-4075-957c-c7223abd6f5f',
#    'date': '1965-02-15'},
#   {'title': 'Beach Boys’ Party!',
#    'id': 'ed5828a0-af00-4852-85b0-e2fd237241f3',
#    'date': '1965-02-15'},
#   {'title': '20 Golden Greats',
#    'id': 'ef71beb1-fd52-3c6e-945e-b835d5a6b19c',
#    'date': '1965-02-15'},
#   {'title': '15 Big Ones',
#    'id': 'eff75200-6bf4-40ca-8647-4c31f2938ff7',
#    'date': '1965-02-15'},
#   {'title': 'The Beach Boys Best',
#    'id': 'f3d5bdec-5ed0-478c-82e1-d156195dd0b3',
#    'date': '1965-02-15'},
#   {'title': 'The Very Best of Beach Boys',
#    'id': 'f9b2b2ed-b6f3-402b-b131-3080b3fa4d43',
#    'date': '1965-02-15'},
#   {'title': 'M.I.U. Album',
#    'id': 'fde6bf8b-89f1-4729-9d66-0da0519f2c92',
#    'date': '1965-02-15'},
#   {'title': 'Holland',
#    'id': 'fe022ed2-38c3-4a8f-8cc0-840eb15f4fd0',
#    'date': '1965-02-15'},
#   {'title': "Surfin' Safari / Surfin' USA",
#    'id': '00883d3a-658c-3c0b-93cb-a89bdd1e7b62',
#    'date': '1965-02-15'},
#   {'title': 'Beach Boys',
#    'id': '06781229-4992-4357-884b-f093c8ef946e',
#    'date': '1965-02-15'},
#   {'title': 'M.I.U. Album',
#    'id': '07252d83-c73e-4520-bf47-01ce66695dbc',
#    'date': '1965-02-15'},
#   {'title': 'Pet Sounds',
#    'id': '085781e0-bd48-3cb4-bd94-d65210bf4850',
#    'date': '1965-02-15'},
#   {'title': 'Endless Summer',
#    'id': '0a9147d5-d413-4811-8f66-7a11f140ff8f',
#    'date': '1965-02-15'},
#   {'title': '"California Dreamin\'"',
#    'id': '0bc0bf54-f959-4609-ad5b-0880b5ffdea5',
#    'date': '1965-02-15'},
#   {'title': 'Summer in Paradise',
#    'id': '0d0e10c5-7349-4ed5-8942-b5a49e024d19',
#    'date': '1965-02-15'},
#   {'title': 'Smiley Smile / Wild Honey',
#    'id': '139ded63-a85f-4ce1-a3da-94c15e2de2f0',
#    'date': '1965-02-15'},
#   {'title': 'Gold Collection',
#    'id': '162478e1-b6de-4821-ae5c-60ef63e2fa00',
#    'date': '1965-02-15'},
#   {'title': 'Surfin’ USA',
#    'id': '17ba65c0-df13-3d20-adf0-feb2ae99f594',
#    'date': '1965-02-15'},
#   {'title': 'California Girls',
#    'id': '19c9fd5e-5962-4516-adae-7a56bec45ead',
#    'date': '1965-02-15'},
#   {'title': 'The Best Of The Beach Boys',
#    'id': '1a413c1f-1845-4d7c-bf00-52f858b2bb6c',
#    'date': '1965-02-15'},
#   {'title': 'The Very Best of the Beach Boys',
#    'id': '23bb3d08-729f-4368-9939-db944fd22dfd',
#    'date': '1965-02-15'},
#   {'title': 'Surfer Girl / Shut Down, Volume 2',
#    'id': '245933e1-0d42-4169-ab10-cbade8554f99',
#    'date': '1965-02-15'},
#   {'title': 'Surfer Girl',
#    'id': '266516ab-4ddc-41b3-a70e-a2d4d011c796',
#    'date': '1965-02-15'},
#   {'title': 'Wild Honey',
#    'id': '27065275-8e6c-30f6-a3d1-203db46b4d50',
#    'date': '1965-02-15'},
#   {'title': 'Super Hits',
#    'id': '2890a207-c324-4b4c-91f7-028f87e10692',
#    'date': '1965-02-15'},
#   {'title': 'L.A. (Light Album)',
#    'id': '2b91b0b1-108e-4e16-b515-0c07207ed696',
#    'date': '1965-02-15'},
#   {'title': 'All-Time Greatest Hits',
#    'id': '2ea73175-4729-443e-90a7-b7f18ca9d0d0',
#    'date': '1965-02-15'},
#   {'title': '16 Superhits',
#    'id': '308031ac-4fb8-447f-ac0d-527ed35c31e6',
#    'date': '1965-02-15'},
#   {'title': 'Surf’s Up',
#    'id': '30f4bea8-27a1-3f55-b436-a804e45fa701',
#    'date': '1965-02-15'},
#   {'title': 'The Beach Boys’ Christmas Album',
#    'id': '312134ba-1a78-4ca8-902d-eaaa5b2195a0',
#    'date': '1965-02-15'},
#   {'title': 'L.A. (Light Album)',
#    'id': '3335c304-62f9-40a0-8a47-aae41ccf2ac6',
#    'date': '1965-02-15'},
#   {'title': 'Holland',
#    'id': '3462c86c-d7ba-4af4-8d66-3d0ec1b74fe7',
#    'date': '1965-02-15'},
#   {'title': 'Little Deuce Coupe',
#    'id': '365ef70b-9988-3a31-8cf6-cac837894ee5',
#    'date': '1965-02-15'},
#   {'title': 'Smiley Smile',
#    'id': '39495bd4-946d-3dcb-883e-c01167c3ddff',
#    'date': '1965-02-15'},
#   {'title': 'Surfer Girl / Shut Down, Volume 2',
#    'id': '3bd49333-b7c7-4b0b-bd0d-ae2198f46cea',
#    'date': '1965-02-15'},
#   {'title': 'Fun Fun Fun: Beach Boys Best',
#    'id': '40082edd-5858-4be7-bf4b-735a4c7b0529',
#    'date': '1965-02-15'},
#   {'title': 'Lost & Found: 1961–1962',
#    'id': '436106c6-03ff-3cf8-89f4-342c222aa5dd',
#    'date': '1965-02-15'},
#   {'title': "Surfin' USA",
#    'id': '4392443d-600e-4fe3-aeec-d472ec43ffa5',
#    'date': '1965-02-15'},
#   {'title': 'Sunflower',
#    'id': '4831d4b1-ef4c-3140-b7b3-b629bd4b0eed',
#    'date': '1965-02-15'},
#   {'title': "Little Deuce Coupe and Other Classic Songs of Drivin' and Draggin'",
#    'id': '48361b53-b2e9-458d-9c3b-7571b88dabd4',
#    'date': '1965-02-15'},
#   {'title': 'Pet Sounds',
#    'id': '4a1f176d-4e05-4276-9afb-d9324d31601f',
#    'date': '1965-02-15'},
#   {'title': 'The Beach Boys Today!',
#    'id': '4c1129e9-a368-34d1-9ac9-88ff276d8313',
#    'date': '1965-02-15'},
#   {'title': 'Concert',
#    'id': '4c68771b-0736-3f51-aaa8-c70358e574da',
#    'date': '1965-02-15'},
#   {'title': 'Surf in the USA',
#    'id': '4d397e45-8070-4e48-8a22-674d5f612851',
#    'date': '1965-02-15'},
#   {'title': 'Greatest Surfing Songs',
#    'id': '4e890929-cf49-459e-8b60-fe525b061126',
#    'date': '1965-02-15'},
#   {'title': 'Special 14 Track CD Sampler',
#    'id': '4f37fa6f-34e3-442a-a1f3-4000563d91b1',
#    'date': '1965-02-15'},
#   {'title': 'The Beach Boys / Jan & Dean / The Ventures',
#    'id': '513c5d39-bb83-4aec-a980-1bf1afdbe4b8',
#    'date': '1965-02-15'},
#   {'title': 'Holland / Mt Vernon and Fairway (A Fairy Tale)',
#    'id': '54746816-f7a2-4d25-987f-4afdcf1d05a3',
#    'date': '1965-02-15'},
#   {'title': 'Pet Sounds',
#    'id': '554484cc-7e87-3066-ab01-12133d9e47ca',
#    'date': '1965-02-15'},
#   {'title': 'Endless Summer',
#    'id': '5ad8cecf-f840-3c90-b8da-e1892b54cb8b',
#    'date': '1965-02-15'},
#   {'title': 'Beach Boys Concert / Live in London',
#    'id': '5b886d2e-26ca-4d7c-b79e-20b0bbef10e9',
#    'date': '1965-02-15'},
#   {'title': 'Endless Summer',
#    'id': '5f99f484-44df-4b5e-8eac-d9e5f5fcee26',
#    'date': '1965-02-15'},
#   {'title': 'Holland',
#    'id': '60543d9a-330a-40e0-ad2d-45bda0f59451',
#    'date': '1965-02-15'},
#   {'title': '20/20',
#    'id': '6139678b-4918-455b-a1f3-7d4c410e38b9',
#    'date': '1965-02-15'},
#   {'title': 'Sunflower',
#    'id': '64f633db-a18d-4bb8-bc34-584a324b8b73',
#    'date': '1965-02-15'},
#   {'title': 'Beach Boys Concert / Live in London',
#    'id': '6590ebf7-7e07-47a9-ad1e-0c98988014f1',
#    'date': '1965-02-15'},
#   {'title': 'All Summer Long',
#    'id': '6881e6a1-412d-306f-8531-7ac1c61f6e9e',
#    'date': '1965-02-15'},
#   {'title': '20 Golden Greats',
#    'id': '6931eec6-a87b-3cbf-86d1-6a90a69ecc1f',
#    'date': '1965-02-15'},
#   {'title': 'The Spirit of the 60s: The Beach Boys',
#    'id': '6ee00853-f248-468f-8841-f4f263f2d7c4',
#    'date': '1965-02-15'},
#   {'title': '15 Big Ones',
#    'id': '769fdcad-210b-4fbb-bb26-fb67c1b790c1',
#    'date': '1965-02-15'},
#   {'title': 'Keepin’ the Summer Alive',
#    'id': '76b99e72-c6c7-43ae-8d4e-6d9636a7bf17',
#    'date': '1965-02-15'},
#   {'title': 'Golden Stars',
#    'id': '77d1df9e-08e0-4b7e-854a-55b94138d293',
#    'date': '1965-02-15'},
#   {'title': 'Christmas Songs',
#    'id': '781ae990-13a0-4b80-965f-9c07e8a1be93',
#    'date': '1965-02-15'},
#   {'title': 'Carl and the Passions: “So Tough”',
#    'id': '785e1919-14c9-4f62-ac80-7af061b4b537',
#    'date': '1965-02-15'},
#   {'title': 'Summer Dreams',
#    'id': '7cbd7ec2-8620-3177-8510-cf01b27ec488',
#    'date': '1965-02-15'},
#   {'title': 'Summer Days (and Summer Nights!!)',
#    'id': '7dbe36d8-f43f-48c1-926e-a799fc9e2c5f',
#    'date': '1965-02-15'},
#   {'title': "Beach Boys' Party! / Stack-o-Tracks",
#    'id': '7de36d51-a7ad-4bef-9950-bf531419aeda',
#    'date': '1965-02-15'},
#   {'title': 'Smiley Smile / Wild Honey',
#    'id': '8896bbd1-0394-38ae-a664-708ebd1a6427',
#    'date': '1965-02-15'},
#   {'title': 'Good Vibrations',
#    'id': '899dfd38-fef6-4394-a515-d5a880788458',
#    'date': '1965-02-15'},
#   {'title': 'Friends',
#    'id': '932ec9d5-2ee2-3312-88e8-9f53534cc88a',
#    'date': '1965-02-15'},
#   {'title': 'Pet Sounds',
#    'id': '93b92312-2d29-4db0-b349-329357a66818',
#    'date': '1965-02-15'},
#   {'title': "Beach Boys' Party! / Stack-O-Tracks",
#    'id': '98da66e4-cdae-4673-8722-ba7b35741140',
#    'date': '1965-02-15'},
#   {'title': 'Pet Sounds',
#    'id': '98dfc557-0755-42f6-9fe2-107bbc0e1485',
#    'date': '1965-02-15'},
#   {'title': 'Summer in Paradise',
#    'id': '994507a3-75c8-42b1-9468-1663bfe900ab',
#    'date': '1965-02-15'},
#   {'title': 'Lost & Found: 1961–1962',
#    'id': 'a1a97e4b-e44c-489a-b30d-c2b2481ad866',
#    'date': '1965-02-15'},
#   {'title': 'California Gold: The Very Best of the Beach Boys',
#    'id': 'a359a4ce-3347-4bd4-9784-c18ab5a11a7d',
#    'date': '1965-02-15'},
#   {'title': "Surfin' Safari - Live",
#    'id': 'a5344edf-bc9c-4ba1-90cd-71ef42f67b1e',
#    'date': '1965-02-15'},
#   {'title': 'The Best of the Beach Boys',
#    'id': 'a56221f6-dea2-45b2-8952-431519fa9b0f',
#    'date': '1965-02-15'},
#   {'title': "Surfin'",
#    'id': 'a9716a8a-6d1c-43d7-9ea1-59899e7f3b5d',
#    'date': '1965-02-15'},
#   {'title': 'Friends / 20/20',
#    'id': 'abd82fb7-df12-4706-9f9a-c2e6f49b0774',
#    'date': '1965-02-15'},
#   {'title': 'Summer in Paradise',
#    'id': 'aee9c38e-0548-4881-9be9-c989efa2eaf2',
#    'date': '1965-02-15'},
#   {'title': 'Shut Down, Volume 2',
#    'id': 'af3eb143-6166-3e3b-b9e7-c9adde3d148a',
#    'date': '1965-02-15'},
#   {'title': 'The Beach Boys',
#    'id': 'b0f37a23-f3c4-4ec6-a5e7-c2cfb59d426c',
#    'date': '1965-02-15'},
#   {'title': 'The Beach Boys',
#    'id': 'b45e2399-53e0-42ae-90c4-27964c43071a',
#    'date': '1965-02-15'},
#   {'title': 'The Absolute Best, Volume 1',
#    'id': 'b8126247-5fb3-4514-9df2-8cb053c54e40',
#    'date': '1965-02-15'},
#   {'title': 'Friends / 20/20',
#    'id': 'bbc9630e-d254-474c-900a-338a8ac9df43',
#    'date': '1965-02-15'},
#   {'title': "The Rock 'n' Roll Era: The Beach Boys: 1962-1967",
#    'id': 'bc961afc-17a6-4321-bdcc-89b29afc3174',
#    'date': '1965-02-15'},
#   {'title': 'The Beach Boys’ Christmas Album',
#    'id': 'be0dcedc-d9c0-46a1-970a-f1405699f7e1',
#    'date': '1965-02-15'},
#   {'title': 'Landlocked',
#    'id': 'be358ff6-89d3-46e1-9e73-2d57ec2fbb5c',
#    'date': '1965-02-15'},
#   {'title': 'Beach Boys’ Party!',
#    'id': 'befe98b0-c6c5-4b4a-88b7-a53c40d3fd8f',
#    'date': '1965-02-15'},
#   {'title': 'Little Deuce Coupe',
#    'id': 'c1e737c2-297a-4081-9989-df32b1fc8e95',
#    'date': '1965-02-15'},
#   {'title': 'The Beach Boys Collection',
#    'id': 'c3dddcb4-a30d-4ee1-b251-bd137e06a6a3',
#    'date': '1965-02-15'},
#   {'title': 'Golden Hits',
#    'id': 'c89c6dde-88e9-43ed-bbcc-5aed2a8d0376',
#    'date': '1965-02-15'},
#   {'title': 'Made in U.S.A.',
#    'id': 'cc35cf76-5ff8-494a-b1a2-592d617ec3d5',
#    'date': '1965-02-15'},
#   {'title': 'Pet Sounds',
#    'id': 'ccbbf352-68d3-4a96-85f4-0a65322381c4',
#    'date': '1965-02-15'},
#   {'title': 'The Beach Boys',
#    'id': 'd8eb912a-d602-4a3f-b337-788b6424db56',
#    'date': '1965-02-15'},
#   {'title': 'The Beach Boys, Collection "Volumen II"',
#    'id': 'de2c8638-da00-4b9b-9484-8443826a401a',
#    'date': '1965-02-15'},
#   {'title': 'Ten Years of Harmony',
#    'id': 'dfe05552-b234-4492-ad32-d4c2e957d506',
#    'date': '1965-02-15'},
#   {'title': 'The Absolute Best, Volume 2',
#    'id': 'e042d6f6-64e1-4549-81c8-4dba474d4c83',
#    'date': '1965-02-15'},
#   {'title': 'Surfin’ USA / Surfer Girl',
#    'id': 'e1bfaa9e-9c0d-4856-a192-0880e282b649',
#    'date': '1965-02-15'},
#   {'title': 'Today! / Summer Days (and Summer Nights!!)',
#    'id': 'e36cc6ee-a659-4346-ab13-3d0978c7b131',
#    'date': '1965-02-15'},
#   {'title': 'Little Deuce Coupe / All Summer Long',
#    'id': 'e94ab2c2-e346-4f78-9527-7efe5d02b35d',
#    'date': '1965-02-15'},
#   {'title': 'Summer Dreams',
#    'id': 'e9e6605b-de1d-4bb7-9021-62beee06e09f',
#    'date': '1965-02-15'},
#   {'title': "Beach Boys' Party! / Stack-O-Tracks",
#    'id': 'ec7a181e-1e8f-4069-bd7e-47d6ded0750f',
#    'date': '1965-02-15'},
#   {'title': 'The Complete Beach Boys: 50 Greatest Hits',
#    'id': 'f3f9c8fc-0204-41f6-9df4-ad306281f438',
#    'date': '1965-02-15'},
#   {'title': 'Ten Years of Harmony',
#    'id': 'f86fb960-7d24-3269-b262-d46bb676b040',
#    'date': '1965-02-15'},
#   {'title': 'Still Cruisin’',
#    'id': 'fbc83a1b-b0ef-4e1a-b232-9209dfd7f654',
#    'date': '1965-02-15'},
#   {'title': 'Surfin’ Safari',
#    'id': 'fc002e9c-e3f2-3f6a-8f7a-75ab6c21d3b3',
#    'date': '1965-02-15'},
#   {'title': 'Summer in Paradise',
#    'id': '00333935-c319-492a-ae37-3f48afd586be',
#    'date': '1965-02-15'},
#   {'title': 'Spirit of Hawaii',
#    'id': '0489c135-683f-4601-9dce-d33937d6a672',
#    'date': '1965-02-15'},
#   {'title': 'All Summer Long',
#    'id': '08c58e6a-1857-4851-99aa-3ebb844a7c14',
#    'date': '1965-02-15'},
#   {'title': 'The Finnish Collection',
#    'id': '1022b4d0-d9df-476f-8895-e9b65cd97fcd',
#    'date': '1965-02-15'},
#   {'title': 'The Best of',
#    'id': '1104f6a8-5e1d-451f-9a6e-19cefe594047',
#    'date': '1965-02-15'},
#   {'title': 'The Greatest Hits: 20 Good Vibrations',
#    'id': '11d442cf-3d25-422d-9c24-cdd26df0e245',
#    'date': '1965-02-15'},
#   {'title': 'Pet Sounds',
#    'id': '158675ac-0b8a-4a4c-9e9e-e27d47928acb',
#    'date': '1965-02-15'},
#   {'title': 'Unsurpassed Masters Vol. 5 (1964)',
#    'id': '17d06d6a-46f5-465c-ae8d-c9f87bf5ac40',
#    'date': '1965-02-15'},
#   {'title': 'The Greatest Hits: 20 Good Vibrations',
#    'id': '1fec2488-45a7-430b-9d83-cac302b9ff6a',
#    'date': '1965-02-15'},
#   {'title': 'The Greatest Hits: 20 Good Vibrations',
#    'id': '2dcc4bf8-baf3-4310-9765-ae8cc6b89e4d',
#    'date': '1965-02-15'},
#   {'title': 'Carl and the Passions: “So Tough” / Holland',
#    'id': '2e3618a5-bbcf-40fe-8e51-d87a9f2f18f3',
#    'date': '1965-02-15'},
#   {'title': 'Unsurpassed Masters Vol. 9 (1965)',
#    'id': '2f900a2b-8fc1-4381-b52f-e620490f0058',
#    'date': '1965-02-15'},
#   {'title': 'Unsurpassed Masters Vol. 3 (1963)',
#    'id': '3455ac53-2003-43d4-ba8a-9cd61e40846c',
#    'date': '1965-02-15'},
#   {'title': 'The Best of The Beach Boys',
#    'id': '37405830-7061-46e1-a3aa-d0a5980c80cf',
#    'date': '1965-02-15'},
#   {'title': 'Beach Boys Christmas',
#    'id': '3770c53e-2329-4912-81ff-c8f7c0471c38',
#    'date': '1965-02-15'},
#   {'title': 'Unsurpassed Masters Vol. 7 (1964)',
#    'id': '3c02b08f-7824-4934-abd3-9f7dbdd2bf29',
#    'date': '1965-02-15'},
#   {'title': 'Unsurpassed Masters Vol. 11 (1965)',
#    'id': '3d177b3a-5625-4b6e-b8f4-8854c53f6c84',
#    'date': '1965-02-15'},
#   {'title': '36 All-Time Greatest Hits',
#    'id': '3dea1cd7-8bae-4f32-9cd4-317a2f0a6e4e',
#    'date': '1965-02-15'},
#   {'title': 'Surfin’ Safari',
#    'id': '43c50c0c-1779-4be2-9008-739fcd216579',
#    'date': '1965-02-15'},
#   {'title': 'Unsurpassed Masters Vol. 14 (1966)',
#    'id': '454431a8-497e-40e3-a71b-c190c1d2a09b',
#    'date': '1965-02-15'},
#   {'title': 'Merry Christmas',
#    'id': '47fecc91-b0aa-4b24-b60d-f1407e82c20d',
#    'date': '1965-02-15'},
#   {'title': 'Merry Christmas from the Beach Boys',
#    'id': '49d99246-36ae-4d61-ac1f-72fef4ad0391',
#    'date': '1965-02-15'},
#   {'title': 'Greatest Hits: The Swedish Collection',
#    'id': '4c549eac-23db-46f0-86b2-b2c6db77aa46',
#    'date': '1965-02-15'},
#   {'title': 'Greatest Hits, Volume Three: The Best of the Brother Years 1970-1986',
#    'id': '4deb0f2c-9cea-4eb7-9aab-9f24c3da29e9',
#    'date': '1965-02-15'},
#   {'title': 'Anthology',
#    'id': '4e3d8922-f0d6-4b74-9570-8b366996fa1d',
#    'date': '1965-02-15'},
#   {'title': 'The Greatest Hits, Volume 2: 20 More Good Vibrations',
#    'id': '4ffff5a3-7ff5-49a1-a7a7-2a973d7750bb',
#    'date': '1965-02-15'},
#   {'title': 'Good Vibrations: Thirty Years of the Beach Boys',
#    'id': '50be98b1-2f26-46f9-8992-04b67d3eb926',
#    'date': '1965-02-15'},
#   {'title': 'The Best of the Beach Boys',
#    'id': '52445960-3679-49e4-8e16-91e30d5f27e0',
#    'date': '1965-02-15'},
#   {'title': 'Stars & Stripes, Volume 1',
#    'id': '55e3fe0b-fd3a-4b67-ada9-e9595b5d7247',
#    'date': '1965-02-15'},
#   {'title': 'Endless Summer',
#    'id': '582142d6-ec36-3bae-8582-29ca8802837e',
#    'date': '1965-02-15'},
#   {'title': "Original Surfin' Hits",
#    'id': '58a70bdc-a61b-4c70-acf3-33c7507055a6',
#    'date': '1965-02-15'},
#   {'title': 'Smiley Smile',
#    'id': '5ad646a9-5159-4494-9caa-f56864bff305',
#    'date': '1965-02-15'},
#   {'title': 'Unsurpassed Masters Vol. 12 (1965)',
#    'id': '5b011688-eae4-45dd-8acf-ead6e1e17059',
#    'date': '1965-02-15'},
#   {'title': 'Perfect Harmony (Essential)',
#    'id': '5f09321e-d196-40b6-ad76-673ba02f2c4d',
#    'date': '1965-02-15'},
#   {'title': 'The Best of The Beach Boys 1970-1986: The Brother Years',
#    'id': '63a87549-9f60-43db-8a2b-dcbc235ed7c7',
#    'date': '1965-02-15'},
#   {'title': 'Unsurpassed Masters Vol. 4 (1963)',
#    'id': '6bb14cff-5639-401f-9d2a-0b561ef71b21',
#    'date': '1965-02-15'},
#   {'title': 'All-Time Greatest Beach Party Hits',
#    'id': '6f768157-f035-425d-b718-884658d225b8',
#    'date': '1965-02-15'},
#   {'title': 'Unsurpassed Masters Vol. 10 (1965)',
#    'id': '6fd4092b-39a4-4a80-815d-81443ab7c0e7',
#    'date': '1965-02-15'},
#   {'title': 'Original Gold',
#    'id': '7109062b-bce5-4533-a4be-58752def0775',
#    'date': '1965-02-15'},
#   {'title': '36 All-Time Greatest Hits',
#    'id': '76446ffb-6ba6-4043-8096-6c339c319ad4',
#    'date': '1965-02-15'},
#   {'title': 'California Girls',
#    'id': '7967b364-499c-43ac-8f6f-e21d18eacc09',
#    'date': '1965-02-15'},
#   {'title': 'The Capitol Years',
#    'id': '79bade78-5f1e-48ae-b1fe-b95eefe669f5',
#    'date': '1965-02-15'},
#   {'title': 'Greatest Hits',
#    'id': '7b652d91-a0b7-49b5-8e58-14fc4319f524',
#    'date': '1965-02-15'},
#   {'title': 'Pet Sounds',
#    'id': '7dc0f5eb-6b62-3611-bc4b-ef5430017b18',
#    'date': '1965-02-15'},
#   {'title': 'Live USA',
#    'id': '8012573c-d83e-4500-a2cb-0e12e8085e00',
#    'date': '1965-02-15'},
#   {'title': 'Pet Sounds',
#    'id': '865cad65-0ee4-4ba3-89e8-66e23e8e0b53',
#    'date': '1965-02-15'},
#   {'title': 'Sunflower / Surf’s Up',
#    'id': '867b6dac-9b48-412f-b844-b1e199672ec0',
#    'date': '1965-02-15'},
#   {'title': 'Ultimate Christmas',
#    'id': '89efb0fd-806a-4802-b8d4-d219652702cc',
#    'date': '1965-02-15'},
#   {'title': 'I Love You',
#    'id': '8b187687-c671-4598-b98c-bf662d8ffe69',
#    'date': '1965-02-15'},
#   {'title': 'Endless Harmony',
#    'id': '8c0a8dbe-93e5-48ff-8b70-e0271df8b4a9',
#    'date': '1965-02-15'},
#   {'title': 'Golden Surf',
#    'id': '8e990921-7392-4795-b2c2-b63be4d41147',
#    'date': '1965-02-15'},
#   {'title': 'Unsurpassed Masters Vol. 2 (1963)',
#    'id': '9369afd0-27cd-4357-8f91-37d8598496e9',
#    'date': '1965-02-15'},
#   {'title': 'Greatest Car Songs',
#    'id': '93b1276d-74ee-40ac-b321-f71d79b39ca9',
#    'date': '1965-02-15'},
#   {'title': 'Pet Sounds',
#    'id': '94af54af-7520-4f4e-bf14-c7e30b2f7eb1',
#    'date': '1965-02-15'},
#   {'title': 'The Greatest Hits: 20 Good Vibrations',
#    'id': '99acd5b3-8016-4bea-a08c-fc182e9e5b4b',
#    'date': '1965-02-15'},
#   {'title': 'The Magic Collection',
#    'id': '9ef3edda-62d0-4120-a21c-14964362cf51',
#    'date': '1965-02-15'},
#   {'title': 'Beach Boys’ Party!',
#    'id': '9f4b54c9-5457-30d2-9a5c-1cc5e46d9171',
#    'date': '1965-02-15'},
#   {'title': 'M.I.U. Album / L.A. (Light Album)',
#    'id': '9f925af3-e419-4491-83cf-53010ee8fc52',
#    'date': '1965-02-15'},
#   {'title': 'Anthology',
#    'id': 'a090ea35-15a6-4b44-842e-69fb78a8203e',
#    'date': '1965-02-15'},
#   {'title': 'Original Legends Versions',
#    'id': 'a2884d44-d890-46ca-9114-07999d3d900d',
#    'date': '1965-02-15'},
#   {'title': "Surfin'",
#    'id': 'a434b478-ffb9-4e5a-8563-2c1c0dcc8834',
#    'date': '1965-02-15'},
#   {'title': 'Heroes and Vibrations',
#    'id': 'a4483cea-72ba-42bc-9ac2-208743fafd20',
#    'date': '1965-02-15'},
#   {'title': 'Christmas Sessions: The Alternative "Beach Boys Christmas" Album',
#    'id': 'a529a028-3eb0-47d5-90ea-10e0eb07327c',
#    'date': '1965-02-15'},
#   {'title': 'Friends',
#    'id': 'a589707a-b145-367b-acf6-af3e0aea00bf',
#    'date': '1965-02-15'},
#   {'title': 'Unsurpassed Masters Vol. 1 (1962)',
#    'id': 'a76bf91f-9841-4bb2-84d9-3b2b150d88f9',
#    'date': '1965-02-15'},
#   {'title': 'Unsurpassed Masters Vol. 19 (1967)',
#    'id': 'aa7092a7-ca85-4999-b3cc-bd0fec7735d3',
#    'date': '1965-02-15'},
#   {'title': 'Spirit of America',
#    'id': 'ac9afad0-9b0c-4309-be1e-dd2b248c0051',
#    'date': '1965-02-15'},
#   {'title': '20 Great Love Songs',
#    'id': 'b1693b2e-feb7-4e93-b785-07baefc528fe',
#    'date': '1965-02-15'},
#   {'title': 'Greatest Hits',
#    'id': 'b16943cd-d114-4d4e-a781-729bd336344c',
#    'date': '1965-02-15'},
#   {'title': 'Good Vibrations: Thirty Years of the Beach Boys - Selections from the 5 CD Box Set',
#    'id': 'b61c418c-10ec-4952-94ec-462664f1ffcd',
#    'date': '1965-02-15'},
#   {'title': 'Endless Harmony',
#    'id': 'bb13fb73-3fbb-4581-9ee1-602c3508fd6a',
#    'date': '1965-02-15'},
#   {'title': '20/20',
#    'id': 'bb40c680-cd01-3126-993a-cbb789b45294',
#    'date': '1965-02-15'},
#   {'title': "Lei'd in Hawaii",
#    'id': 'bcddaa7f-2a0f-4dc8-81d9-aed19703d3fa',
#    'date': '1965-02-15'},
#   {'title': 'Unsurpassed Masters Vol. 13 (1965-1966)',
#    'id': 'bd7eccd9-c5db-4cd9-9d14-96b5b47da47d',
#    'date': '1965-02-15'},
#   {'title': 'Surfer Girl / Shut Down, Volume 2',
#    'id': 'c2288bce-ebe1-3cb4-b5aa-8392e3faa361',
#    'date': '1965-02-15'},
#   {'title': '15 Big Ones / Love You',
#    'id': 'c393404d-7126-4a93-a111-a8462160f252',
#    'date': '1965-02-15'},
#   {'title': "Let's Go Surfin'",
#    'id': 'c42e7f27-1f2f-4ab0-bb38-f7ced521035d',
#    'date': '1965-02-15'},
#   {'title': 'The Pet Sounds Sessions',
#    'id': 'c4d98de5-8365-444a-8ba7-420459ad63cf',
#    'date': '1965-02-15'},
#   {'title': "Surfin' U.S.A.",
#    'id': 'c608c1fe-a04b-48e3-88e8-6694df07fb51',
#    'date': '1965-02-15'},
#   {'title': "Keepin' the Summer Alive / The Beach Boys",
#    'id': 'ccf585ac-d1af-4a46-914e-6e05d705caf8',
#    'date': '1965-02-15'},
#   {'title': 'Unsurpassed Masters Vol. 15 (1966)',
#    'id': 'cdffb271-d9ec-425c-8c34-7d8ac7a01cd6',
#    'date': '1965-02-15'},
#   {'title': 'Greatest Hits',
#    'id': 'd13d1532-6892-47f9-b686-bc2c86365e81',
#    'date': '1965-02-15'},
#   {'title': 'Greatest Hits',
#    'id': 'd73a2a3f-e301-4011-b00c-3ac342a12b7f',
#    'date': '1965-02-15'},
#   {'title': 'Surfin’ Safari / Surfin’ USA',
#    'id': 'd80a2996-1282-3378-9464-bb21b7a72fc8',
#    'date': '1965-02-15'},
#   {'title': 'Unsurpassed Masters Vol. 8 (1965)',
#    'id': 'dc9538ab-f1f8-4a11-87a9-9445b8216788',
#    'date': '1965-02-15'},
#   {'title': 'Endless Harmony',
#    'id': 'ddbe46b9-59e3-4fde-b395-55beab0bcf1c',
#    'date': '1965-02-15'},
#   {'title': 'Smiley Smile',
#    'id': 'de67f5f3-149a-4828-aea2-6c314f7db660',
#    'date': '1965-02-15'},
#   {'title': 'The Live Box (1965-1968)',
#    'id': 'de9034c7-6740-4be7-9c85-7ad73cd15b60',
#    'date': '1965-02-15'},
#   {'title': 'The Greatest Hits: 20 Good Vibrations',
#    'id': 'e1a8c68d-cde8-4eff-b610-3aa21811d622',
#    'date': '1965-02-15'},
#   {'title': 'Smile: Unsurpassed Masters, Vol. 16 (1966–1967)',
#    'id': 'e3eef221-381a-46d1-9a04-89a9d78db39c',
#    'date': '1965-02-15'},
#   {'title': 'Merry Christmas',
#    'id': 'e4f0e00b-acbe-4085-93c5-4183fce6a9c1',
#    'date': '1965-02-15'},
#   {'title': 'Good Vibrations: Thirty Years of the Beach Boys',
#    'id': 'e787de17-11e0-4ba2-a47b-863e5185ba0c',
#    'date': '1965-02-15'},
#   {'title': 'The Wonderful World of the Beach Boys: 26 Greatest Hits',
#    'id': 'e8e6d5f7-2e44-4bbe-9213-025de0d3ac94',
#    'date': '1965-02-15'},
#   {'title': 'The Best of the Beach Boys',
#    'id': 'ea0c87c8-9805-46ac-bb62-cc16b8e6b260',
#    'date': '1965-02-15'},
#   {'title': 'Unsurpassed Masters, Vol. 17 (1966-1967): Smile Sessions',
#    'id': 'ea48ca71-ec4c-46b7-b7d3-8d0d3ffb0e79',
#    'date': '1965-02-15'},
#   {'title': 'Californian Days',
#    'id': 'f1e06164-2861-4e87-a3ed-e01800370b4a',
#    'date': '1965-02-15'},
#   {'title': 'In Concert',
#    'id': 'f50d5954-adbc-4e00-9079-22b9db00f12a',
#    'date': '1965-02-15'},
#   {'title': 'Pet Sounds',
#    'id': 'f55076af-861f-41a1-9bf7-f4b47942a3d4',
#    'date': '1965-02-15'},
#   {'title': 'The Greatest Hits, Volume 1: 20 Good Vibrations',
#    'id': 'fad73632-8420-45d3-b797-b4a8588f3cd4',
#    'date': '1965-02-15'},
#   {'title': 'Unsurpassed Masters Vol. 6 (1964)',
#    'id': 'fdb0461c-858a-474d-910f-02cf003807dd',
#    'date': '1965-02-15'},
#   {'title': 'Shut Down, Volume 2',
#    'id': '03706044-9dfc-418b-9bbd-eeea5e302de7',
#    'date': '1965-02-15'},
#   {'title': 'The Smile Sessions',
#    'id': '10f10323-5670-408a-8032-873a80e30b6d',
#    'date': '1965-02-15'},
#   {'title': 'Summer Love Songs',
#    'id': '11c9708b-6c13-48f0-b144-0368770dd90a',
#    'date': '1965-02-15'},
#   {'title': 'All Summer Long',
#    'id': '15086851-2dd8-45e7-ac20-bf56664347bd',
#    'date': '1965-02-15'},
#   {'title': 'Classics Selected by Brian Wilson',
#    'id': '195306c6-f8d1-3110-b295-186e4cdb6841',
#    'date': '1965-02-15'},
#   {'title': 'Christmas With the Beach Boys',
#    'id': '1a863696-89b8-445d-a04b-7b465a9c35f9',
#    'date': '1965-02-15'},
#   {'title': 'The Smile Sessions',
#    'id': '1bc13541-1212-40ea-85e6-1633a56e88f1',
#    'date': '1965-02-15'},
#   {'title': 'Pet Sounds',
#    'id': '201744ef-d473-4874-ba66-0df817beaa49',
#    'date': '1965-02-15'},
#   {'title': 'Live at Knebworth 1980, Volume Two',
#    'id': '2283527f-7a31-4a4d-b2b7-0168c3d45f3b',
#    'date': '1965-02-15'},
#   {'title': 'Pet Sounds',
#    'id': '23ed1f85-c5d0-4dce-877e-54225ce968dd',
#    'date': '1965-02-15'},
#   {'title': 'Pet Sounds',
#    'id': '2a5041d9-bfe3-390c-802e-727425dc0ceb',
#    'date': '1965-02-15'},
#   {'title': 'Beach Boys & Friends, Volume 2',
#    'id': '2c7adf26-406b-4137-9602-ec8fa4230e26',
#    'date': '1965-02-15'},
#   {'title': 'Smiley Smile / Wild Honey',
#    'id': '2fcb8fcd-5aa6-3404-b6e0-218b76ccd976',
#    'date': '1965-02-15'},
#   {'title': 'Pet Sounds: 40th Anniversary',
#    'id': '32bf1c97-ca3f-4f69-92d7-b143728574a2',
#    'date': '1965-02-15'},
#   {'title': 'Greatest Hits',
#    'id': '351f0c4b-da96-40af-914b-82c8ae79b53c',
#    'date': '1965-02-15'},
#   {'title': 'Live at Knebworth 1980',
#    'id': '358bd812-7410-4bea-96a9-525f8eeb4f55',
#    'date': '1965-02-15'},
#   {'title': 'The Great Beach Boys',
#    'id': '36c3bbd1-d17a-4b8b-8844-05c6622e9b4d',
#    'date': '1965-02-15'},
#   {'title': 'The Platinum Collection',
#    'id': '37f72cff-31d3-452c-9827-08caab152460',
#    'date': '1965-02-15'},
#   {'title': 'The Platinum Collection',
#    'id': '38b2dbf5-2a47-468c-a07b-79578423e5d0',
#    'date': '1965-02-15'},
#   {'title': 'Sights and Sounds of Summer: The Very Best of the Beach Boys',
#    'id': '397a18c4-5593-4f1b-a9c4-dcd62db1d1d6',
#    'date': '1965-02-15'},
#   {'title': 'Hits of the Beach Boys',
#    'id': '3b2c21cd-3984-4c70-b2b1-533c76ad6c33',
#    'date': '1965-02-15'},
#   {'title': 'Music Ages, Volume 7: The Beach Boys',
#    'id': '3d066d45-101e-4a2d-a7ac-e02f2e75a5eb',
#    'date': '1965-02-15'},
#   {'title': 'The Beach Boys’ Christmas Album',
#    'id': '3ff3555d-0636-4a02-adbf-c6dc220b2f4a',
#    'date': '1965-02-15'},
#   {'title': 'Pet Sounds',
#    'id': '41c8cbb9-c20a-41ec-b832-50efa8f835c6',
#    'date': '1965-02-15'},
#   {'title': 'The Best',
#    'id': '443102df-706a-4875-adad-d30c14fae006',
#    'date': '1965-02-15'},
#   {'title': 'Sounds of Summer: The Very Best of the Beach Boys',
#    'id': '44d0cab3-7f42-31b4-a920-c52a84cd8de9',
#    'date': '1965-02-15'},
#   {'title': 'Pet Sounds',
#    'id': '498bddd0-b8cf-4691-850f-296bd008138f',
#    'date': '1965-02-15'},
#   {'title': 'Beach Boys’ Party!',
#    'id': '4e9b3d0b-7006-474a-8d67-1bccc4de0543',
#    'date': '1965-02-15'},
#   {'title': 'Friends / 20/20',
#    'id': '4ed621c7-e901-3bd4-8be3-0df261d75f73',
#    'date': '1965-02-15'},
#   {'title': 'L.A. (Light Album)',
#    'id': '4fa6a8e2-6e33-41e1-8aff-2354e8a8923a',
# ...
#   {'title': 'Live in Sacramento 1964',
#    'id': '377b97a8-1f5f-41fe-851d-f97e082e851b',
#    'date': '1965-02-15'},
#   {'title': 'Icon',
#    'id': '38fdf3ed-a3f3-4568-8762-ee06df685bad',
#    'date': '1965-02-15'},
#   {'title': 'The Beach Boys Today!',
#    'id': '3d204935-ef22-4ee8-a2c0-e337ac142748',
#    'date': '1965-02-15'},
#   {'title': 'Becoming The Beach Boys: The Complete Hite & Dorinda Morgan Sessions',
#    'id': '3e9ee816-d879-44a8-ba84-14390bf7aea7',
#    'date': '1965-02-15'},
#   {'title': 'SMiLE (soniclovenoize 1967 stereo mix)',
#    'id': '3f8763ee-0f96-4215-94ea-1bd0d2112988',
#    'date': '1965-02-15'},
#   {'title': 'Smiley Smile',
#    'id': '4765c3b4-55ce-4875-acbe-e091914f11e7',
#    'date': '1965-02-15'},
#   {'title': 'SMiLE (soniclovenoize 1967 mix)',
#    'id': '491a234d-f414-4aec-8753-b8e7ed249173',
#    'date': '1965-02-15'},
#   {'title': 'Surfin’ Safari',
#    'id': '4a5493a9-e21e-4907-b85a-580be0c51c1b',
#    'date': '1965-02-15'},
#   {'title': "Limited Edition 50th Anniversary Collection 'ZinePak",
#    'id': '4ae61260-5061-4f65-89cc-2d809e86cecd',
#    'date': '1965-02-15'},
#   {'title': 'The Beach Boys’ Christmas Album',
#    'id': '5058ff70-1220-456d-8aba-0554229f05fe',
#    'date': '1965-02-15'},
#   {'title': 'In Concert',
#    'id': '51b37e62-3c84-4d3e-8d1e-d08b4a7a97e0',
#    'date': '1965-02-15'},
#   {'title': 'Pet Sounds ...the definitive authorized story of the album',
#    'id': '51b71fcb-5f05-4526-a7be-87231967b06c',
#    'date': '1965-02-15'},
#   {'title': 'Surfer Girl',
#    'id': '525a4149-5b1f-46c9-add7-93c640440795',
#    'date': '1965-02-15'},
#   {'title': 'The Beach Boys Today!',
#    'id': '53e23d2b-6e76-41c7-87a3-4271a2b95fbe',
#    'date': '1965-02-15'},
#   {'title': 'The Beach Boys’ Christmas Album',
#    'id': '53e8115a-76f6-4c2c-a81c-0b4c01a300e7',
#    'date': '1965-02-15'},
#   {'title': '15 Big Ones',
#    'id': '550b6c6d-98a3-4162-ac7c-3065dbb7ff47',
#    'date': '1965-02-15'},
#   {'title': 'The Beach Boys’ Christmas Album',
#    'id': '55994ef3-a31d-40b8-8d8c-4c4e58a59a1c',
#    'date': '1965-02-15'},
#   {'title': 'Summer Days (and Summer Nights!!)',
#    'id': '562dfa8c-534e-4bb3-badd-c26a7687faca',
#    'date': '1965-02-15'},
#   {'title': 'Smiley Smile',
#    'id': '5aee80ba-d81c-47e8-b20d-8a2f39668fea',
#    'date': '1965-02-15'},
#   {'title': '1967: Sunshine Tomorrow',
#    'id': '5b6bbd01-dd41-47eb-afc5-fee2bec6ea0b',
#    'date': '1965-02-15'},
#   {'title': 'All Summer Long',
#    'id': '5dc50407-366f-4ba3-866e-64e12ac47545',
#    'date': '1965-02-15'},
#   {'title': 'Surfin’ USA',
#    'id': '62c11d20-01ac-44dd-ac49-bed482d2711f',
#    'date': '1965-02-15'},
#   {'title': 'The Beach Boys Today!',
#    'id': '65ca525e-90e7-4224-bdf8-c7098a9159f2',
#    'date': '1965-02-15'},
#   {'title': 'Beach Boys’ Party!',
#    'id': '65dedd2f-35e8-48c2-9b8a-c2c5c303edc9',
#    'date': '1965-02-15'},
#   {'title': 'All Summer Long',
#    'id': '69f38851-65b4-40bd-843e-577081c365f8',
#    'date': '1965-02-15'},
#   {'title': 'All Summer Long',
#    'id': '6b924096-8f64-47d6-b696-faab4d42ca3a',
#    'date': '1965-02-15'},
#   {'title': 'Keepin’ the Summer Alive',
#    'id': '6e9a1864-fd0a-44b3-8eec-7d0375fd0b7b',
#    'date': '1965-02-15'},
#   {'title': 'Smiley Smile',
#    'id': '6f019fec-5c73-4ea4-a2ea-cd9eb7053e3d',
#    'date': '1965-02-15'},
#   {'title': 'Icon 2',
#    'id': '72ada4d8-2a25-4680-9ff4-ec62bdd2fe75',
#    'date': '1965-02-15'},
#   {'title': 'Sunflower',
#    'id': '72b1e7a7-1b14-45e4-96ea-2c380a628b5a',
#    'date': '1965-02-15'},
#   {'title': 'Pet Sounds',
#    'id': '733171d8-149d-4238-8fc8-5ce25cada17e',
#    'date': '1965-02-15'},
#   {'title': 'Golden Selections',
#    'id': '73b575a0-364c-4365-ae3a-0b331926c6cc',
#    'date': '1965-02-15'},
#   {'title': 'M.I.U. Album',
#    'id': '7f677ee3-f5cb-4dfe-8b95-d629d0edca80',
#    'date': '1965-02-15'},
#   {'title': 'Graduation Day 1966: Live at the University of Michigan',
#    'id': '89c5e3da-408b-46cc-8478-088780f76d74',
#    'date': '1965-02-15'},
#   {'title': 'Wild Honey',
#    'id': '89e668df-3e14-459e-ad64-896fadb20e81',
#    'date': '1965-02-15'},
#   {'title': 'Shut Down, Volume 2',
#    'id': '8b187f2a-3d34-403d-bb68-3765ef76c97f',
#    'date': '1965-02-15'},
#   {'title': 'Surfer Girl',
#    'id': '8b8748a6-6f43-4854-ada2-36a03e7788c9',
#    'date': '1965-02-15'},
#   {'title': "Surfin' U.S.A. and Greatest Hits",
#    'id': '8ccaa644-9e98-448b-b57b-13af5f7ab420',
#    'date': '1965-02-15'},
#   {'title': 'Pet Sounds',
#    'id': '8f8420ae-866d-4a7a-943a-c82a49d64411',
#    'date': '1965-02-15'},
#   {'title': '1967: Sunshine Tomorrow',
#    'id': '9198c4c4-f074-46ae-b57c-a900d3163026',
#    'date': '1965-02-15'},
#   {'title': 'Smiley Smile',
#    'id': '93978fac-1e76-4993-8dc3-0ed37dcb3bcf',
#    'date': '1965-02-15'},
#   {'title': 'Holland',
#    'id': '94c4b302-e1ff-4832-bb19-5612fb57413d',
#    'date': '1965-02-15'},
#   {'title': 'Pet Sounds',
#    'id': '951f402c-6186-4561-b3b5-f64d26ecf49b',
#    'date': '1965-02-15'},
#   {'title': '20th Century Masters: The Millennium Collection: 10 Great Songs',
#    'id': '96dfa82c-60f3-4939-b32f-5132a520f696',
#    'date': '1965-02-15'},
#   {'title': '1967: Live Sunshine',
#    'id': '97b94b5d-f4af-45a2-81d1-97898932ae61',
#    'date': '1965-02-15'},
#   {'title': 'Summer Days (and Summer Nights!!)',
#    'id': '9b44292f-2242-4fb8-ae44-00851576b70f',
#    'date': '1965-02-15'},
#   {'title': 'All Summer Long',
#    'id': '9bc87757-091a-4b52-bc84-c3b6944f73b4',
#    'date': '1965-02-15'},
#   {'title': 'Pet Sounds',
#    'id': '9de804cf-8a14-44a0-8e10-da47a24e39c3',
#    'date': '1965-02-15'},
#   {'title': 'The Beach Boys Today!',
#    'id': 'a85adc82-0722-40df-aa65-8c574be3c55b',
#    'date': '1965-02-15'},
#   {'title': 'Pet Sounds',
#    'id': 'a915d5b4-509f-4037-be89-3899016e06aa',
#    'date': '1965-02-15'},
#   {'title': 'Shut Down, Volume 2',
#    'id': 'aa6ab286-8ac4-4c31-81e5-91514ba9d8b6',
#    'date': '1965-02-15'},
#   {'title': 'Surfin’ Safari',
#    'id': 'b176e7c0-b69b-4b7a-bd34-4c5a1e44dfe9',
#    'date': '1965-02-15'},
#   {'title': 'Pet Sounds',
#    'id': 'b5474125-17b3-4893-ba39-267b28ba9fb3',
#    'date': '1965-02-15'},
#   {'title': 'Friends',
#    'id': 'b922e265-6018-4438-a40b-a8fc4f407386',
#    'date': '1965-02-15'},
#   {'title': 'Surf’s Up',
#    'id': 'b9ed9e50-5322-4ef0-8f14-980764a3ae35',
#    'date': '1965-02-15'},
#   {'title': 'Live in Chicago 1965',
#    'id': 'bad02168-2dbe-46b0-8497-0fca6cce99fe',
#    'date': '1965-02-15'},
#   {'title': 'Beach Boys’ Party!',
#    'id': 'bbe52b1e-db40-4ebf-8fd2-2c72d82e2bcd',
#    'date': '1965-02-15'},
#   {'title': '20/20',
#    'id': 'c133a049-4dc0-40e2-b864-884028386b63',
#    'date': '1965-02-15'},
#   {'title': 'Summer Days (and Summer Nights!!)',
#    'id': 'c418a575-109e-445c-a480-3e354a9efcbf',
#    'date': '1965-02-15'},
#   {'title': 'Live: The 50th Anniversary Tour',
#    'id': 'c91d1547-2ec1-4fd2-964f-a52007082f5a',
#    'date': '1965-02-15'},
#   {'title': '20/20',
#    'id': 'cd6d02f3-ec11-4793-8f5a-f4b7f0b7a144',
#    'date': '1965-02-15'},
#   {'title': 'Smiley Smile',
#    'id': 'ce614399-69a0-4b54-bbe4-8267f107acd6',
#    'date': '1965-02-15'},
#   {'title': 'Beach Boys Concert',
#    'id': 'ce69b177-c779-4ec9-b333-3d4f1396e318',
#    'date': '1965-02-15'},
#   {'title': 'Love You',
#    'id': 'cecdf7da-22bc-457f-a926-02f6c1a0c819',
#    'date': '1965-02-15'},
#   {'title': 'Pet Sounds',
#    'id': 'd2936468-5dcb-4c2e-8d14-eb2ae3eecb75',
#    'date': '1965-02-15'},
#   {'title': 'Smiley Smile',
#    'id': 'd35a489f-6003-4d1f-aa8b-0fb135d4d21c',
#    'date': '1965-02-15'},
#   {'title': 'Surf’s Up',
#    'id': 'd54c9a87-f325-4914-a9ad-29978b61f5e6',
#    'date': '1965-02-15'},
#   {'title': 'Little Deuce Coupe',
#    'id': 'd686ca43-3d20-4251-93b5-926adbac977a',
#    'date': '1965-02-15'},
#   {'title': 'Summer Days (and Summer Nights!!)',
#    'id': 'd8a95e5d-9840-4db2-b1cf-bb968fa0844c',
#    'date': '1965-02-15'},
#   {'title': 'Holland',
#    'id': 'da4bdd75-09af-4182-a168-78b43f7aa425',
#    'date': '1965-02-15'},
#   {'title': 'Surfin’ Safari',
#    'id': 'dba92694-40b0-4e75-9c8a-7bfbb1638df5',
#    'date': '1965-02-15'},
#   {'title': '1967: Sunshine Tomorrow',
#    'id': 'e1340e7a-c7f2-4a2b-a0ed-4361efebc584',
#    'date': '1965-02-15'},
#   {'title': 'The Beach Boys',
#    'id': 'e230a928-6c02-4741-a58f-103cf4e58600',
#    'date': '1965-02-15'},
#   {'title': 'Surfer Girl',
#    'id': 'e2dea0ba-fd08-4137-a72c-0cf266e0f7c5',
#    'date': '1965-02-15'},
#   {'title': "Surfin' Safari",
#    'id': 'e3a309cb-936b-4f35-b102-69e4b9269f98',
#    'date': '1965-02-15'},
#   {'title': 'Beach Boys Concert',
#    'id': 'e4db90e1-6c93-4763-872c-b80ff7ce7046',
#    'date': '1965-02-15'},
#   {'title': 'The Beach Boys Today!',
#    'id': 'e745e42b-1cf7-45d3-a7d9-e2a5219a33fa',
#    'date': '1965-02-15'},
#   {'title': 'Smiley Smile',
#    'id': 'ef525afe-fcea-4949-9d8b-fe91d363a1bf',
#    'date': '1965-02-15'},
#   {'title': 'Surf’s Up',
#    'id': 'ef893871-9414-4d07-b6e2-72d58d15bb65',
#    'date': '1965-02-15'},
#   {'title': 'Pet Sounds',
#    'id': 'f04cce33-b9a0-4bed-af11-f84d649652b2',
#    'date': '1965-02-15'},
#   {'title': 'Live at Knebworth',
#    'id': 'f1b6e676-9599-4a81-b1f8-76631215a407',
#    'date': '1965-02-15'},
#   {'title': 'US Single Collection',
#    'id': 'fb32fbab-ba29-436b-9afd-95b901fcee6a',
#    'date': '1965-02-15'},
#   {'title': '1967: Sunshine Tomorrow',
#    'id': 'fb493499-73d1-4c97-9746-ef0a5f5df7fd',
#    'date': '1965-02-15'},
#   {'title': 'L.A. (Light Album)',
#    'id': 'ff6838f7-59ba-416e-b9d3-ad1426076b55',
#    'date': '1965-02-15'},
#   {'title': '20 Golden Greats',
#    'id': '014fe40d-3221-4c74-b340-508b3701046f',
#    'date': '1965-02-15'},
#   {'title': 'On Tour: 1968',
#    'id': '01a8464c-5d42-4aa4-80c4-e9249f912cee',
#    'date': '1965-02-15'},
#   {'title': 'Smile (Second Edition)',
#    'id': '029cd6d6-4ba7-4f11-b38c-a5c6286aba34'},
#   {'title': 'No Surfing Today',
#    'id': '0a0789e6-d5eb-446a-9457-3f9f4dd98337',
#    'date': '1965-02-15'},
#   {'title': '20 Greatest Hits',
#    'id': '0e5f37ec-551f-4580-be69-41a6a0047f27',
#    'date': '1965-02-15'},
#   {'title': 'Endless Summer',
#    'id': '0eb989b8-fb63-38a6-84a2-a4cbff93bd4a',
#    'date': '1965-02-15'},
#   {'title': 'The Beach Boys With the Royal Philharmonic Orchestra',
#    'id': '14a8619b-9369-42f7-a42e-faeddf3ac5b0',
#    'date': '1965-02-15'},
#   {'title': '1982-11-26: Jamaica World Music Festival, Montego Bay, Jamaica',
#    'id': '150c4b98-3f89-4b8b-972e-aac68614c00d'},
#   {'title': 'Landlocked', 'id': '1763cbf7-dcb2-4171-a4eb-c09a3dab45fc'},
#   {'title': 'Holland / Mount Vernon And Fairway',
#    'id': '1970668f-8313-4e4d-81d0-a21721e1954b'},
#   {'title': '20 Golden Hits', 'id': '19e9514e-198f-4fd1-9a9f-77d53b0362b8'},
#   {'title': 'Best of the Beach Boys, Volume 1',
#    'id': '1b48c930-66c3-43f8-a752-be2b23221fc5'},
#   {'title': '1971-06-27: Live at the Fillmore East',
#    'id': '24d5b155-d2f0-472f-b767-88453b705eae'},
#   {'title': 'Unsurpassed Masters Vol. 21 (1965) Today & Summer Days (And Summer Nights!)',
#    'id': '2a1e926a-4bf3-4f7c-8475-f256a979694d'},
#   {'title': 'Shut Down, Volume 2',
#    'id': '2a7a3227-51df-4db8-8ab5-cbb50dda3d5e'},
#   {'title': "Surf's Up",
#    'id': '2fd2d5f2-36c0-48f0-978e-f4a890b09ef8',
#    'date': '1965-02-15'},
#   {'title': 'Greatest Hits: The Danish Collection',
#    'id': '327bb91f-b0d2-4041-87ae-b1e816fc70e6'},
#   {'title': 'Made in U.S.A.', 'id': '35584295-2b25-4a6a-90cb-37be387f2b9c'},
#   {'title': 'The Beach Boys Summer Hits',
#    'id': '3693b8e6-982e-4fea-b6fc-f685052204a9',
#    'date': '1965-02-15'},
#   {'title': 'The Very Best of the Beach Boys',
#    'id': '3853c2dc-e08d-42ed-ae8b-c3a1cec1d1e4'},
#   {'title': 'Smile', 'id': '38fbf6bd-31d9-4544-9bbd-743a9dedd604'},
#   {'title': "Surfin' USA", 'id': '3d35aa50-7e59-41dc-a53d-263a3ca879bf'},
#   {'title': '50 Greatest Hits: The Complete Beach Boys',
#    'id': '44b754d6-d426-435d-8cc6-389fc7b79e38'},
#   {'title': '1974-06-14: Nassau Coliseum, Uniondale, NY, USA',
#    'id': '460e19bc-b0d6-4608-97bf-85cf6d29cc4b'},
#   {'title': 'The Cocaine Sessions',
#    'id': '464c5c05-5637-4ef3-b1bb-c037e2effc84'},
#   {'title': 'Beach Boys Greatest Hits',
#    'id': '5ed86407-7686-4428-ad6d-cc7d2952153d'},
#   {'title': 'The Album',
#    'id': '609c4533-96c0-49b3-900f-de727319f9f9',
#    'date': '1965-02-15'},
#   {'title': 'Endless Summer',
#    'id': '63d841b2-09c4-4bb2-b470-9ad5b4a3cb84',
#    'date': '1965-02-15'},
#   {'title': 'Unsurpassed Masters Vol. 18 (1967) The Alternate Smiley Smile Album',
#    'id': '6933db71-31d9-4640-97c0-3204a866d5d0'},
#   {'title': 'Classics Selected by Brian Wilson',
#    'id': '6b5ca86e-2c1f-462c-b8b2-d79944dfb019',
#    'date': '1965-02-15'},
#   {'title': 'Rehearsal 1967', 'id': '7033efaf-61af-4db2-9708-7caa61b4d5ca'},
#   {'title': 'Endless Summer',
#    'id': '7ccde054-1c3d-41c5-ba01-e2882ce911eb',
#    'date': '1965-02-15'},
#   {'title': 'Dumb Angel, Volume 2',
#    'id': '7ff7d4a7-1188-4551-98ce-35029335d4aa'},
#   {'title': 'Sunflower',
#    'id': '89484cf5-2a60-46af-9f11-8cfeb5f03492',
#    'date': '1965-02-15'},
#   {'title': 'The Beach Boys With the Royal Philharmonic Orchestra',
#    'id': '8e495964-3218-4dd7-97d8-4f1c4f4f496c',
#    'date': '1965-02-15'},
#   {'title': 'Super Hits', 'id': '924fb07d-fae7-4c3d-aee7-18e01987a135'},
#   {'title': 'Landlocked / Adult Child',
#    'id': '940cb5a6-5134-470a-b5b9-c22c54f6fbb4'},
#   {'title': 'The Best Of The Beach Boys Vol. 3',
#    'id': '95510e5d-aca7-4ed8-96eb-6492dad77168',
#    'date': '1965-02-15'},
#   {'title': 'I Can Hear Music: The 20/20 Sessions',
#    'id': '955ee8f4-135f-485a-ace5-51d0c67ba939',
#    'date': '1965-02-15'},
#   {'title': 'Unsurpassed Masters Vol. 20 (1968-1969)',
#    'id': '989888b4-d7d8-4df6-b06d-107bab91c1bf'},
#   {'title': 'Little Deuce Coupe',
#    'id': 'a26b2ede-bbcc-41a2-ba04-bda186d41ff4'},
#   {'title': 'Unreleased Gems', 'id': 'a31d4ba7-7e0b-47f5-8bfd-ec50f0628c96'},
#   {'title': 'Endless Summer',
#    'id': 'a3a02aa1-962c-499c-9168-7be14b5f89be',
#    'date': '1965-02-15'},
#   {'title': 'Summer in Paradise',
#    'id': 'a80c9d0b-5142-4636-b8f0-4cc3b291dcf4'},
#   {'title': 'The Beach Boys’ Christmas Album',
#    'id': 'ab7a0ba0-85ca-432f-aacb-af4993b8b3f0',
#    'date': '1965-02-15'},
#   {'title': '1967: Sunshine Tomorrow 2: The Studio Sessions',
#    'id': 'abc5c517-43d7-4d9b-977f-549ee5afb281',
#    'date': '1965-02-15'},
#   {'title': 'Platinum: The Ultimate Collection',
#    'id': 'ac1f9f94-3660-452d-9a1e-c70cee6b2314'},
#   {'title': 'The Absolute Best, Volume 2',
#    'id': 'ac2d9ce9-5871-41ff-aa25-ecdc22775d27',
#    'date': '1965-02-15'},
#   {'title': 'The Smile Sessions',
#    'id': 'b6f5eb19-54ca-4369-920b-fdaade95251c'},
#   {'title': 'Spirit of America',
#    'id': 'b8d8c9f4-38c6-479f-8dad-ba4184008a31',
#    'date': '1965-02-15'},
#   {'title': 'Best Selection', 'id': 'b976c876-7ea3-4535-92ff-113bb1238f60'},
#   {'title': 'Summer Crush: Songs We Love to Love',
#    'id': 'bcad57be-45fb-44a9-849e-16058ed8520e'},
#   {'title': 'The Beach Boys With the Royal Philharmonic Orchestra',
#    'id': 'c2ee0287-445a-4255-a255-98f82dd5db66',
#    'date': '1965-02-15'},
#   {'title': 'Smile', 'id': 'c8ff6754-45f7-4db6-b44d-f42985c1ae40'},
#   {'title': 'Good Vibrations - Smile',
#    'id': 'cb8f864a-1000-4209-b876-a0a3a8c5bcca'},
#   {'title': 'I Get Around',
#    'id': 'ce6cd328-9db8-415f-84ce-9dfaf894a0e5',
#    'date': '1965-02-15'},
#   {'title': 'Best of the Beach Boys',
#    'id': 'd0f9cb52-0235-4123-8d49-5f4645ff37d2'},
#   {'title': 'Wake the World: The Friends Sessions',
#    'id': 'd1fd8103-05f0-40c1-9af3-47f642ba6a61',
#    'date': '1965-02-15'},
#   {'title': 'Surfin’ Safari',
#    'id': 'dd7048d0-58e7-4458-b7a1-89eebed58009',
#    'date': '1965-02-15'},
#   {'title': 'Pet Sounds', 'id': 'dea54a9f-9338-4865-b7d5-c4e8eb9d8d9c'},
#   {'title': 'Great Artist Series',
#    'id': 'dea889c4-9154-4819-bd78-71b30168d548',
#    'date': '1965-02-15'},
#   {'title': 'The Best of the Beach Boys, Volume 2',
#    'id': 'e49f3ed0-68bb-4a12-8d14-b607fb0b26f0'},
#   {'title': 'Live USA, Vol. 1',
#    'id': 'edf59299-f0a2-4275-8a28-0ce7285c47ab',
#    'date': '1965-02-15'},
#   {'title': "Surfin' U.S.A.",
#    'id': 'f080a7ef-5688-4d2e-8102-1d801729b420',
#    'date': '1965-02-15'},
#   {'title': 'SMiLE', 'id': 'f243cb29-ed9a-4adc-b9f4-0fecbe48e720'},
#   {'title': 'Landlocked', 'id': 'f4451d4b-f9b2-4430-937d-909ac1788a9d'},
#   {'title': '32 Great Songs',
#    'id': 'f7d4152b-9c7c-437a-ad05-7bf9156222dd',
#    'date': '1965-02-15'}]}
