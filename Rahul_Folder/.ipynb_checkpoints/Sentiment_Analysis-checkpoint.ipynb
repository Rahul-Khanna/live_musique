# %%
import pickle
import jsonlines
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer 
import tqdm

# %%
artist_reivews = {}
with jsonlines.open('../data_for_558_proj/songkick.jl') as reader:
    for obj in reader:
        if len(obj["reviews"]) > 0:
            text = " ".join(obj["reviews"])
            text = " ".join(text.split()).strip()
            artist_reivews[obj["url"]] = {"text" : text,
                                          "count" : len(obj["reviews"]),
                                          "name" : obj["name"]}

# %%
list(artist_reivews.keys())[0]
# Out:
# 'https://www.songkick.com/artists/268425-beach-boys'

# %%
sid_obj = SentimentIntensityAnalyzer() 
for key in tqdm.tqdm(list(artist_reivews.keys())):
    artist_reivews[key]["sentiment"] = sid_obj.polarity_scores(artist_reivews[key]["text"])
# Out:
# 100%|██████████| 4971/4971 [12:02<00:00,  6.88it/s]

# %%
urls = list(artist_reivews.keys())

# %%
review_sentiment = {key : artist_reivews[key]["sentiment"] for key in urls}

# %%
# with open("nlp_data/review_sentiment.p", "wb") as f:
#     pickle.dump(review_sentiment, f)

# %%
artist_reivews[urls[0]]["sentiment"]
# Out:
# {'neg': 0.027, 'neu': 0.745, 'pos': 0.228, 'compound': 1.0}

# %%
# https://github.com/cjhutto/vaderSentiment#about-the-scoring
sentiment = []
pos_scores = []
neg_scores = []
for url in tqdm.tqdm(urls):
    sentiment_scores = review_sentiment[url]
    if sentiment_scores["compound"] > 0.05:
        pos_scores.append(sentiment_scores["pos"])
        sentiment.append("pos")
    elif sentiment_scores["compound"] < -0.05:
        neg_scores.append(sentiment_scores["neg"])
        sentiment.append("neg")
    else:
        sentiment.append("n")
# Out:
# 100%|██████████| 4971/4971 [00:00<00:00, 247535.14it/s]

# %%
import numpy as np

# %%
pos_mean = np.mean(pos_scores)
pos_stdev = np.std(pos_scores)

# %%
pos_mean, pos_stdev
# Out:
# (0.21904841675178757, 0.06681115661824748)

# %%
neg_mean = np.mean(neg_scores)
neg_stdev = np.std(neg_scores)

# %%
neg_mean, neg_stdev
# Out:
# (0.14885483870967747, 0.12720263828342676)

# %%
z_score_sentiments = {}
for url in tqdm.tqdm(urls):
    sentiment_scores = review_sentiment[url]
    if sentiment_scores["compound"] > 0.05:
        z_score_sentiments[url] = {
            "sentiment" : "pos",
            "z-score" : (sentiment_scores["pos"] - pos_mean) / pos_stdev
        }
    elif sentiment_scores["compound"] < -0.05:
        z_score_sentiments[url] = {
            "sentiment" : "neg",
            "z-score" : (sentiment_scores["neg"] - neg_mean) / neg_stdev
        }
    else:
        z_score_sentiments[url] = {
            "sentiment" : "neutral",
            "z-score" : 0
        }
# Out:
# 100%|██████████| 4971/4971 [00:00<00:00, 337033.21it/s]

# %%
z_score_sentiments
# Out:
# {'https://www.songkick.com/artists/268425-beach-boys': {'sentiment': 'pos',
#   'z-score': 0.13398335998523303},
#  'https://www.songkick.com/artists/255691-erykah-badu': {'sentiment': 'pos',
#   'z-score': -0.7191675639793454},
#  'https://www.songkick.com/artists/7061074-becky-g': {'sentiment': 'pos',
#   'z-score': -1.018518765370426},
#  'https://www.songkick.com/artists/330792-lloyd': {'sentiment': 'pos',
#   'z-score': -2.1261182105174226},
#  'https://www.songkick.com/artists/44022-slash': {'sentiment': 'pos',
#   'z-score': 0.059145559637462916},
#  'https://www.songkick.com/artists/172258-tom-jones': {'sentiment': 'pos',
#   'z-score': 0.8374586832542716},
#  'https://www.songkick.com/artists/402995-martina-mcbride': {'sentiment': 'pos',
#   'z-score': -1.078389005648642},
#  'https://www.songkick.com/artists/4183826-christine-and-the-queens': {'sentiment': 'pos',
#   'z-score': 0.4632696815154211},
#  'https://www.songkick.com/artists/492798-red-velvet': {'sentiment': 'pos',
#   'z-score': 1.585836686731972},
#  'https://www.songkick.com/artists/600176-matt-simons': {'sentiment': 'pos',
#   'z-score': 1.017069404088919},
#  'https://www.songkick.com/artists/142639-michael-mcdonald': {'sentiment': 'pos',
#   'z-score': 0.14895092005478705},
#  'https://www.songkick.com/artists/429056-beats-antique': {'sentiment': 'pos',
#   'z-score': 0.6428804023500694},
#  'https://www.songkick.com/artists/2785886-susan-boyle': {'sentiment': 'pos',
#   'z-score': 1.1218423245757974},
#  'https://www.songkick.com/artists/487843-amadou-and-mariam': {'sentiment': 'pos',
#   'z-score': -0.7191675639793454},
#  'https://www.songkick.com/artists/301317-wild-child': {'sentiment': 'pos',
#   'z-score': 1.585836686731972},
#  'https://www.songkick.com/artists/453899-me-first-and-the-gimme-gimmes': {'sentiment': 'pos',
#   'z-score': -0.4946541629360355},
#  'https://www.songkick.com/artists/290708-kris-kristofferson': {'sentiment': 'pos',
#   'z-score': 0.4782372415849751},
#  'https://www.songkick.com/artists/304164-young-dro': {'sentiment': 'pos',
#   'z-score': -1.6471562882916941},
#  'https://www.songkick.com/artists/1154482-jezabels': {'sentiment': 'pos',
#   'z-score': -0.6592973237011297},
#  'https://www.songkick.com/artists/1493236-chelsea-grin': {'sentiment': 'pos',
#   'z-score': 0.388431881167651},
#  'https://www.songkick.com/artists/186864-sammy-hagar': {'sentiment': 'pos',
#   'z-score': 0.7177182026978395},
#  'https://www.songkick.com/artists/517644-heatwave': {'sentiment': 'pos',
#   'z-score': -0.7940053643271155},
#  'https://www.songkick.com/artists/5349183-duckwrth': {'sentiment': 'pos',
#   'z-score': -0.5844595233533596},
#  'https://www.songkick.com/artists/576907-john-grant': {'sentiment': 'pos',
#   'z-score': 0.418367001306759},
#  'https://www.songkick.com/artists/150912-moguai': {'sentiment': 'pos',
#   'z-score': -0.3000758820318332},
#  'https://www.songkick.com/artists/509603-tiffany': {'sentiment': 'pos',
#   'z-score': -0.10549760112763133},
#  'https://www.songkick.com/artists/276729-lil-boosie': {'sentiment': 'pos',
#   'z-score': -0.46471904279692744},
#  'https://www.songkick.com/artists/365563-bouncing-souls': {'sentiment': 'pos',
#   'z-score': -0.4198163625882654},
#  'https://www.songkick.com/artists/273540-mr-oizo': {'sentiment': 'pos',
#   'z-score': -1.9016048094741123},
#  'https://www.songkick.com/artists/335294-ben-lee': {'sentiment': 'pos',
#   'z-score': -0.6443297636315757},
#  'https://www.songkick.com/artists/6104509-dylan-scott': {'sentiment': 'pos',
#   'z-score': 1.091907204436689},
#  'https://www.songkick.com/artists/884052-mat-zo': {'sentiment': 'neg',
#   'z-score': 0.23698534635071428},
#  'https://www.songkick.com/artists/8262768-meduza': {'sentiment': 'pos',
#   'z-score': 1.9151230082621595},
#  'https://www.songkick.com/artists/331894-ray-parker-jr': {'sentiment': 'pos',
#   'z-score': -0.10549760112763133},
#  'https://www.songkick.com/artists/8413103-japanese-breakfast': {'sentiment': 'pos',
#   'z-score': 0.7027506426282855},
#  'https://www.songkick.com/artists/8672779-alice-merton': {'sentiment': 'pos',
#   'z-score': -0.1504002813362934},
#  'https://www.songkick.com/artists/500572-andrew-wk': {'sentiment': 'pos',
#   'z-score': -0.2102705216145095},
#  'https://www.songkick.com/artists/3836701-tv-girl': {'sentiment': 'pos',
#   'z-score': 0.6279128422805154},
#  'https://www.songkick.com/artists/26322-alphabeat': {'sentiment': 'pos',
#   'z-score': -0.12046516119718535},
#  'https://www.songkick.com/artists/7939688-dmas': {'sentiment': 'pos',
#   'z-score': 2.0198959287490377},
#  'https://www.songkick.com/artists/193054-umphreys-mcgee': {'sentiment': 'pos',
#   'z-score': -1.1681943660659662},
#  'https://www.songkick.com/artists/8480018-kap-g': {'sentiment': 'pos',
#   'z-score': 0.2537238405416648},
#  'https://www.songkick.com/artists/3690671-anthem-lights': {'sentiment': 'pos',
#   'z-score': 1.9151230082621595},
#  'https://www.songkick.com/artists/2267192-ben-pearce': {'sentiment': 'pos',
#   'z-score': -0.10549760112763133},
#  'https://www.songkick.com/artists/447030-corey-hart': {'sentiment': 'pos',
#   'z-score': 0.5381074818631912},
#  'https://www.songkick.com/artists/229667-sizzla': {'sentiment': 'pos',
#   'z-score': 0.4932048016545291},
#  'https://www.songkick.com/artists/456238-mercury-rev': {'sentiment': 'pos',
#   'z-score': -0.7341351240488995},
#  'https://www.songkick.com/artists/701937-tamar-braxton': {'sentiment': 'pos',
#   'z-score': 1.3912584058277697},
#  'https://www.songkick.com/artists/1574625-chris-lane': {'sentiment': 'pos',
#   'z-score': 1.4211935259668778},
#  'https://www.songkick.com/artists/6538089-mome': {'sentiment': 'pos',
#   'z-score': -1.7968318889872341},
#  'https://www.songkick.com/artists/402984-pete-rock': {'sentiment': 'pos',
#   'z-score': -1.392707767109276},
#  'https://www.songkick.com/artists/200273-adam-sandler': {'sentiment': 'pos',
#   'z-score': 0.044177999567908896},
#  'https://www.songkick.com/artists/219341-bonnie-prince-billy': {'sentiment': 'pos',
#   'z-score': -0.8239404844662236},
#  'https://www.songkick.com/artists/532177-ben-kweller': {'sentiment': 'pos',
#   'z-score': -0.40484880251871136},
#  'https://www.songkick.com/artists/57419-wire': {'sentiment': 'pos',
#   'z-score': -0.40484880251871136},
#  'https://www.songkick.com/artists/137863-health': {'sentiment': 'pos',
#   'z-score': 0.3135940808198809},
#  'https://www.songkick.com/artists/8686719-night-lovell': {'sentiment': 'pos',
#   'z-score': -0.10549760112763133},
#  'https://www.songkick.com/artists/8438813-i-love-makonnen': {'sentiment': 'pos',
#   'z-score': -1.392707767109276},
#  'https://www.songkick.com/artists/6567113-grizfolk': {'sentiment': 'pos',
#   'z-score': 1.032036964158473},
#  'https://www.songkick.com/artists/446174-shura': {'sentiment': 'pos',
#   'z-score': 0.418367001306759},
#  'https://www.songkick.com/artists/248932-jars-of-clay': {'sentiment': 'pos',
#   'z-score': -0.07556248098852328},
#  'https://www.songkick.com/artists/233066-sabaton': {'sentiment': 'pos',
#   'z-score': 0.1938536002634491},
#  'https://www.songkick.com/artists/981579-shovels-and-rope': {'sentiment': 'pos',
#   'z-score': 0.059145559637462916},
#  'https://www.songkick.com/artists/279699-every-time-i-die': {'sentiment': 'pos',
#   'z-score': -0.12046516119718535},
#  'https://www.songkick.com/artists/152387-danger-mouse': {'sentiment': 'neg',
#   'z-score': -0.2268415113009254},
#  'https://www.songkick.com/artists/296955-lea-salonga': {'sentiment': 'pos',
#   'z-score': 0.2686914006112188},
#  'https://www.songkick.com/artists/652964-rubens': {'sentiment': 'pos',
#   'z-score': -0.7491026841184535},
#  'https://www.songkick.com/artists/200103-syleena-johnson': {'sentiment': 'pos',
#   'z-score': -1.078389005648642},
#  'https://www.songkick.com/artists/186747-buju-banton': {'sentiment': 'pos',
#   'z-score': 0.5530750419327453},
#  'https://www.songkick.com/artists/93920-whitechapel': {'sentiment': 'pos',
#   'z-score': 0.4932048016545291},
#  'https://www.songkick.com/artists/607684-felix-cartal': {'sentiment': 'pos',
#   'z-score': -1.2579997264832898},
#  'https://www.songkick.com/artists/550709-emf': {'sentiment': 'pos',
#   'z-score': -1.2579997264832898},
#  'https://www.songkick.com/artists/583312-framing-hanley': {'sentiment': 'pos',
#   'z-score': -1.123291685857304},
#  'https://www.songkick.com/artists/388463-nina-sky': {'sentiment': 'pos',
#   'z-score': -0.4497514827273734},
#  'https://www.songkick.com/artists/6321339-lane-8': {'sentiment': 'pos',
#   'z-score': 0.8224911231847176},
#  'https://www.songkick.com/artists/555504-crystal-waters': {'sentiment': 'pos',
#   'z-score': -1.4974806875961542},
#  'https://www.songkick.com/artists/186428-hombres-g': {'sentiment': 'pos',
#   'z-score': 0.6578479624196234},
#  'https://www.songkick.com/artists/1991033-civil-twilight': {'sentiment': 'pos',
#   'z-score': -1.377740207039722},
#  'https://www.songkick.com/artists/501888-dan-deacon': {'sentiment': 'pos',
#   'z-score': -1.4825131275266001},
#  'https://www.songkick.com/artists/401781-john-waite': {'sentiment': 'pos',
#   'z-score': 1.1368098846453514},
#  'https://www.songkick.com/artists/126229-lalah-hathaway': {'sentiment': 'pos',
#   'z-score': 0.4632696815154211},
#  'https://www.songkick.com/artists/499335-woods': {'sentiment': 'pos',
#   'z-score': 0.044177999567908896},
#  'https://www.songkick.com/artists/428244-airbourne': {'sentiment': 'pos',
#   'z-score': 0.6428804023500694},
#  'https://www.songkick.com/artists/273634-jermaine-dupri': {'sentiment': 'pos',
#   'z-score': -1.587286048013478},
#  'https://www.songkick.com/artists/569193-bear-hands': {'sentiment': 'pos',
#   'z-score': 0.8973289235324877},
#  'https://www.songkick.com/artists/1993972-getter': {'sentiment': 'pos',
#   'z-score': 0.8224911231847176},
#  'https://www.songkick.com/artists/481970-judy-garland': {'sentiment': 'pos',
#   'z-score': -2.0363128501000984},
#  'https://www.songkick.com/artists/2498311-r5': {'sentiment': 'pos',
#   'z-score': 1.630739366940634},
#  'https://www.songkick.com/artists/3207596-ummet-ozcan': {'sentiment': 'pos',
#   'z-score': -1.6920589685003562},
#  'https://www.songkick.com/artists/92422-lyle-lovett': {'sentiment': 'pos',
#   'z-score': 0.9272640436715958},
#  'https://www.songkick.com/artists/203736-berliner-philharmoniker': {'sentiment': 'pos',
#   'z-score': -1.7070265285699102},
#  'https://www.songkick.com/artists/1507780-jain': {'sentiment': 'pos',
#   'z-score': -0.2102705216145095},
#  'https://www.songkick.com/artists/11333-dead-can-dance': {'sentiment': 'pos',
#   'z-score': 1.017069404088919},
#  'https://www.songkick.com/artists/491621-oddisee': {'sentiment': 'pos',
#   'z-score': 1.047004524228027},
#  'https://www.songkick.com/artists/489691-molotov': {'sentiment': 'pos',
#   'z-score': -1.4675455674570461},
#  'https://www.songkick.com/artists/393675-gang-of-four': {'sentiment': 'pos',
#   'z-score': 0.08908067977657096},
#  'https://www.songkick.com/artists/413460-young-fathers': {'sentiment': 'pos',
#   'z-score': -0.8089729243966696},
#  'https://www.songkick.com/artists/947784-milo-greene': {'sentiment': 'pos',
#   'z-score': 0.6578479624196234},
#  'https://www.songkick.com/artists/398664-key': {'sentiment': 'pos',
#   'z-score': 1.8851878881230515},
#  'https://www.songkick.com/artists/119484-whispers': {'sentiment': 'pos',
#   'z-score': -0.31504344210138724},
#  'https://www.songkick.com/artists/316022-little-river-band': {'sentiment': 'pos',
#   'z-score': 1.1667450047844594},
#  'https://www.songkick.com/artists/5212623-max-frost': {'sentiment': 'pos',
#   'z-score': 0.6578479624196234},
#  'https://www.songkick.com/artists/237150-cracker': {'sentiment': 'pos',
#   'z-score': -0.060594920918969265},
#  'https://www.songkick.com/artists/4059111-tedeschi-trucks-band': {'sentiment': 'pos',
#   'z-score': 0.6129452822109613},
#  'https://www.songkick.com/artists/6418354-little-simz': {'sentiment': 'pos',
#   'z-score': 2.0198959287490377},
#  'https://www.songkick.com/artists/4078461-snow-tha-product': {'sentiment': 'pos',
#   'z-score': 1.2565503652017835},
#  'https://www.songkick.com/artists/409713-brandon-heath': {'sentiment': 'pos',
#   'z-score': 0.6279128422805154},
#  'https://www.songkick.com/artists/75208-nonpoint': {'sentiment': 'pos',
#   'z-score': 0.1938536002634491},
#  'https://www.songkick.com/artists/6257514-ibeyi': {'sentiment': 'pos',
#   'z-score': 1.2565503652017835},
#  'https://www.songkick.com/artists/800753-underachievers': {'sentiment': 'pos',
#   'z-score': 0.044177999567908896},
#  'https://www.songkick.com/artists/252954-coasters': {'sentiment': 'pos',
#   'z-score': 0.08908067977657096},
#  'https://www.songkick.com/artists/281441-mako': {'sentiment': 'pos',
#   'z-score': -0.4497514827273734},
#  'https://www.songkick.com/artists/466926-method-man-and-redman': {'sentiment': 'pos',
#   'z-score': -0.3000758820318332},
#  'https://www.songkick.com/artists/407165-devildriver': {'sentiment': 'pos',
#   'z-score': 0.9272640436715958},
#  'https://www.songkick.com/artists/265432-wilson-phillips': {'sentiment': 'pos',
#   'z-score': -1.1831619261355197},
#  'https://www.songkick.com/artists/547191-brian-wilson': {'sentiment': 'pos',
#   'z-score': -0.40484880251871136},
#  'https://www.songkick.com/artists/564271-justin-nozuka': {'sentiment': 'pos',
#   'z-score': 1.4810637662450938},
#  'https://www.songkick.com/artists/8580909-shallou': {'sentiment': 'pos',
#   'z-score': 0.10404823984612498},
#  'https://www.songkick.com/artists/76901-ben-harper-and-the-innocent-criminals': {'sentiment': 'pos',
#   'z-score': 0.28365896068077284},
#  'https://www.songkick.com/artists/2373357-zola-jesus': {'sentiment': 'pos',
#   'z-score': 0.059145559637462916},
#  'https://www.songkick.com/artists/350562-mum': {'sentiment': 'pos',
#   'z-score': -1.093356565718196},
#  'https://www.songkick.com/artists/68457-nappy-roots': {'sentiment': 'pos',
#   'z-score': 0.13398335998523303},
#  'https://www.songkick.com/artists/256120-los-lonely-boys': {'sentiment': 'pos',
#   'z-score': 0.10404823984612498},
#  'https://www.songkick.com/artists/136137-ralph-tresvant': {'sentiment': 'pos',
#   'z-score': -0.07556248098852328},
#  'https://www.songkick.com/artists/438608-dwele': {'sentiment': 'pos',
#   'z-score': -0.6293622035620217},
#  'https://www.songkick.com/artists/256163-sebastian': {'sentiment': 'pos',
#   'z-score': -1.362772646970168},
#  'https://www.songkick.com/artists/554312-millencolin': {'sentiment': 'pos',
#   'z-score': -0.6892324438402377},
#  'https://www.songkick.com/artists/5120858-giraffage': {'sentiment': 'pos',
#   'z-score': -1.03348632543998},
#  'https://www.songkick.com/artists/393320-score': {'sentiment': 'pos',
#   'z-score': 1.3313881655495536},
#  'https://www.songkick.com/artists/403194-cradle-of-filth': {'sentiment': 'pos',
#   'z-score': -0.030659800779861218},
#  'https://www.songkick.com/artists/86228-zion': {'sentiment': 'pos',
#   'z-score': -1.2280646063441818},
#  'https://www.songkick.com/artists/127791-cosmic-gate': {'sentiment': 'pos',
#   'z-score': -0.6143946434924676},
#  'https://www.songkick.com/artists/6008004-asap-twelvyy': {'sentiment': 'pos',
#   'z-score': -0.3599461223100493},
#  'https://www.songkick.com/artists/4518683-angel-haze': {'sentiment': 'pos',
#   'z-score': -0.46471904279692744},
#  'https://www.songkick.com/artists/312232-this-will-destroy-you': {'sentiment': 'pos',
#   'z-score': -0.7191675639793454},
#  'https://www.songkick.com/artists/1077783-j-boog': {'sentiment': 'pos',
#   'z-score': 0.5530750419327453},
#  'https://www.songkick.com/artists/9144339-yung-pinch': {'sentiment': 'pos',
#   'z-score': -2.171020890726085},
#  'https://www.songkick.com/artists/8481198-nora-en-pure': {'sentiment': 'pos',
#   'z-score': -0.7042000039097918},
#  'https://www.songkick.com/artists/268604-devin-the-dude': {'sentiment': 'pos',
#   'z-score': -0.8239404844662236},
#  'https://www.songkick.com/artists/372766-ohio-players': {'sentiment': 'pos',
#   'z-score': -0.12046516119718535},
#  'https://www.songkick.com/artists/424937-toadies': {'sentiment': 'pos',
#   'z-score': -0.4497514827273734},
#  'https://www.songkick.com/artists/210930-elohim': {'sentiment': 'pos',
#   'z-score': 1.1667450047844594},
#  'https://www.songkick.com/artists/5250053-jmsn': {'sentiment': 'pos',
#   'z-score': 0.9272640436715958},
#  'https://www.songkick.com/artists/378240-format': {'sentiment': 'pos',
#   'z-score': -1.1831619261355197},
#  'https://www.songkick.com/artists/397405-rachael-yamagata': {'sentiment': 'pos',
#   'z-score': 1.017069404088919},
#  'https://www.songkick.com/artists/68521-tracy-lawrence': {'sentiment': 'pos',
#   'z-score': 0.6428804023500694},
#  'https://www.songkick.com/artists/6942219-charlotte-day-wilson': {'sentiment': 'pos',
#   'z-score': -2.0363128501000984},
#  'https://www.songkick.com/artists/446271-riton': {'sentiment': 'pos',
#   'z-score': -1.8417345691958962},
#  'https://www.songkick.com/artists/76223-banda-los-recoditos': {'sentiment': 'pos',
#   'z-score': -1.1382592459268581},
#  'https://www.songkick.com/artists/597552-karen-o': {'sentiment': 'pos',
#   'z-score': -0.5694919632838056},
#  'https://www.songkick.com/artists/356939-mark-lanegan': {'sentiment': 'pos',
#   'z-score': -0.2252380816840635},
#  'https://www.songkick.com/artists/9902029-murda-beatz': {'sentiment': 'pos',
#   'z-score': -0.09053004105807731},
#  'https://www.songkick.com/artists/5467058-andy-mineo': {'sentiment': 'pos',
#   'z-score': 0.5680426020022993},
#  'https://www.songkick.com/artists/25030-steel-pulse': {'sentiment': 'pos',
#   'z-score': 0.029210439498354872},
#  'https://www.songkick.com/artists/5019063-summer-salt': {'sentiment': 'pos',
#   'z-score': 1.9151230082621595},
#  'https://www.songkick.com/artists/235316-stray-cats': {'sentiment': 'pos',
#   'z-score': -0.18033540147540145},
#  'https://www.songkick.com/artists/326697-bebel-gilberto': {'sentiment': 'pos',
#   'z-score': 0.29862652075032686},
#  'https://www.songkick.com/artists/433558-afters': {'sentiment': 'pos',
#   'z-score': 0.5830101620718533},
#  'https://www.songkick.com/artists/82388-murs': {'sentiment': 'pos',
#   'z-score': 0.29862652075032686},
#  'https://www.songkick.com/artists/185297-chip': {'sentiment': 'neg',
#   'z-score': 6.604777798856277},
#  'https://www.songkick.com/artists/1849982-jack-penate': {'sentiment': 'pos',
#   'z-score': -1.9315399296132203},
#  'https://www.songkick.com/artists/6922004-troyboi': {'sentiment': 'pos',
#   'z-score': 0.23875628047211075},
#  'https://www.songkick.com/artists/205161-sleaterkinney': {'sentiment': 'pos',
#   'z-score': -1.1681943660659662},
#  'https://www.songkick.com/artists/22900-streetlight-manifesto': {'sentiment': 'pos',
#   'z-score': 0.3435292009589889},
#  'https://www.songkick.com/artists/15807-los-angeles-azules': {'sentiment': 'pos',
#   'z-score': -1.4675455674570461},
#  'https://www.songkick.com/artists/189548-anya-marina': {'sentiment': 'pos',
#   'z-score': 0.5381074818631912},
#  'https://www.songkick.com/artists/332532-modeselektor': {'sentiment': 'pos',
#   'z-score': 0.029210439498354872},
#  'https://www.songkick.com/artists/596190-jim-james': {'sentiment': 'pos',
#   'z-score': -0.19530296154495547},
#  'https://www.songkick.com/artists/951289-tensnake': {'sentiment': 'pos',
#   'z-score': -0.33001100217094126},
#  'https://www.songkick.com/artists/6134219-pegboard-nerds': {'sentiment': 'pos',
#   'z-score': -0.3599461223100493},
#  'https://www.songkick.com/artists/8653309-parcels': {'sentiment': 'pos',
#   'z-score': 1.061972084297581},
#  'https://www.songkick.com/artists/28995-julie-andrews': {'sentiment': 'pos',
#   'z-score': -1.437610447317938},
#  'https://www.songkick.com/artists/502774-mop': {'sentiment': 'pos',
#   'z-score': -1.8567021292654502},
#  'https://www.songkick.com/artists/38464-chris-cagle': {'sentiment': 'pos',
#   'z-score': -0.8838107247444397},
#  'https://www.songkick.com/artists/385711-peach-pit': {'sentiment': 'pos',
#   'z-score': 1.570869126662418},
#  'https://www.songkick.com/artists/145766-cannibal-corpse': {'sentiment': 'pos',
#   'z-score': -0.5245892830751435},
#  'https://www.songkick.com/artists/516945-kutless': {'sentiment': 'pos',
#   'z-score': 0.1938536002634491},
#  'https://www.songkick.com/artists/8982309-elevation-worship': {'sentiment': 'pos',
#   'z-score': 2.259376889861902},
#  'https://www.songkick.com/artists/1171574-la-dispute': {'sentiment': 'pos',
#   'z-score': 0.388431881167651},
#  'https://www.songkick.com/artists/2829061-passion': {'sentiment': 'pos',
#   'z-score': 1.3463557256191077},
#  'https://www.songkick.com/artists/404681-los-tigres-del-norte': {'sentiment': 'pos',
#   'z-score': -1.003551205300872},
#  'https://www.songkick.com/artists/1447663-yuck': {'sentiment': 'pos',
#   'z-score': -1.9614750497523283},
#  'https://www.songkick.com/artists/304656-clay-walker': {'sentiment': 'pos',
#   'z-score': -0.0007246806407531735},
#  'https://www.songkick.com/artists/160544-little-feat': {'sentiment': 'pos',
#   'z-score': -0.7640702441880075},
#  'https://www.songkick.com/artists/927192-timber-timbre': {'sentiment': 'pos',
#   'z-score': 0.3435292009589889},
#  'https://www.songkick.com/artists/2496911-rival-sons': {'sentiment': 'pos',
#   'z-score': 0.029210439498354872},
#  'https://www.songkick.com/artists/450639-rupaul': {'sentiment': 'pos',
#   'z-score': -1.437610447317938},
#  'https://www.songkick.com/artists/163372-nitty-gritty-dirt-band': {'sentiment': 'pos',
#   'z-score': 0.4782372415849751},
#  'https://www.songkick.com/artists/529090-ryuichi-sakamoto': {'sentiment': 'pos',
#   'z-score': -0.9436809650226557},
#  'https://www.songkick.com/artists/58149-ride': {'sentiment': 'pos',
#   'z-score': 0.5081723617240832},
#  'https://www.songkick.com/artists/963793-sango': {'sentiment': 'pos',
#   'z-score': -0.4347839226578194},
#  'https://www.songkick.com/artists/239240-nine-days': {'sentiment': 'pos',
#   'z-score': -0.07556248098852328},
#  'https://www.songkick.com/artists/8656934-barns-courtney': {'sentiment': 'pos',
#   'z-score': 1.1218423245757974},
#  'https://www.songkick.com/artists/186001-heartless-bastards': {'sentiment': 'pos',
#   'z-score': 0.6129452822109613},
#  'https://www.songkick.com/artists/475787-rasmus': {'sentiment': 'pos',
#   'z-score': 1.2415828051322295},
#  'https://www.songkick.com/artists/197544-il-divo': {'sentiment': 'pos',
#   'z-score': -0.46471904279692744},
#  'https://www.songkick.com/artists/10071927-ali-gatie': {'sentiment': 'pos',
#   'z-score': -0.9436809650226557},
#  'https://www.songkick.com/artists/511014-blaze': {'sentiment': 'pos',
#   'z-score': 1.1817125648540134},
#  'https://www.songkick.com/artists/314612-paulina-rubio': {'sentiment': 'pos',
#   'z-score': 0.10404823984612498},
#  'https://www.songkick.com/artists/427327-foy-vance': {'sentiment': 'pos',
#   'z-score': 0.5830101620718533},
#  'https://www.songkick.com/artists/59663-eric-benet': {'sentiment': 'pos',
#   'z-score': 0.8823613634629337},
#  'https://www.songkick.com/artists/621069-firebeatz': {'sentiment': 'pos',
#   'z-score': -1.2879348466223979},
#  'https://www.songkick.com/artists/382312-steven-curtis-chapman': {'sentiment': 'pos',
#   'z-score': 0.6728155224891774},
#  'https://www.songkick.com/artists/419837-sasha': {'sentiment': 'pos',
#   'z-score': 0.014242879428800849},
#  'https://www.songkick.com/artists/404687-plumb': {'sentiment': 'pos',
#   'z-score': 0.43333456137631304},
#  'https://www.songkick.com/artists/8591704-filous': {'sentiment': 'pos',
#   'z-score': 3.801035577025965},
#  'https://www.songkick.com/artists/49302-toad-the-wet-sprocket': {'sentiment': 'pos',
#   'z-score': 0.5381074818631912},
#  'https://www.songkick.com/artists/323600-tink': {'sentiment': 'pos',
#   'z-score': -0.7491026841184535},
#  'https://www.songkick.com/artists/35855-len': {'sentiment': 'pos',
#   'z-score': -0.5395568431446975},
#  'https://www.songkick.com/artists/4392693-2cellos': {'sentiment': 'pos',
#   'z-score': 0.8973289235324877},
#  'https://www.songkick.com/artists/9190454-hrvy': {'sentiment': 'pos',
#   'z-score': 2.5138254110443206},
#  'https://www.songkick.com/artists/7810644-hillsong-young-and-free': {'sentiment': 'pos',
#   'z-score': 3.1274953738960347},
#  'https://www.songkick.com/artists/503627-project-pat': {'sentiment': 'pos',
#   'z-score': -0.8239404844662236},
#  'https://www.songkick.com/artists/1355870-j-alvarez': {'sentiment': 'pos',
#   'z-score': -2.0363128501000984},
#  'https://www.songkick.com/artists/6856644-oh-hellos': {'sentiment': 'pos',
#   'z-score': 1.032036964158473},
#  'https://www.songkick.com/artists/9072919-grandson': {'sentiment': 'pos',
#   'z-score': 0.942231603741149},
#  'https://www.songkick.com/artists/8914674-syml': {'sentiment': 'pos',
#   'z-score': 1.8702203280534975},
#  'https://www.songkick.com/artists/165622-dj-koze': {'sentiment': 'pos',
#   'z-score': -1.377740207039722},
#  'https://www.songkick.com/artists/511909-attila': {'sentiment': 'pos',
#   'z-score': 1.091907204436689},
#  'https://www.songkick.com/artists/533166-bayside': {'sentiment': 'pos',
#   'z-score': 0.5381074818631912},
#  'https://www.songkick.com/artists/474582-electric-six': {'sentiment': 'pos',
#   'z-score': 0.7626208829065015},
#  'https://www.songkick.com/artists/207184-melvins': {'sentiment': 'pos',
#   'z-score': -0.3449785622404953},
#  'https://www.songkick.com/artists/28087-bt': {'sentiment': 'pos',
#   'z-score': -1.8417345691958962},
#  'https://www.songkick.com/artists/22233-born-ruffians': {'sentiment': 'pos',
#   'z-score': 0.7326857627673935},
#  'https://www.songkick.com/artists/2948141-he-is-we': {'sentiment': 'pos',
#   'z-score': -0.38988124244915734},
#  'https://www.songkick.com/artists/118198-joan-osborne': {'sentiment': 'pos',
#   'z-score': -0.5096217230055895},
#  'https://www.songkick.com/artists/221350-dj-quik': {'sentiment': 'pos',
#   'z-score': -0.4497514827273734},
#  'https://www.songkick.com/artists/168302-juan-luis-guerra': {'sentiment': 'pos',
#   'z-score': 0.07411311970701694},
#  'https://www.songkick.com/artists/150716-big-brother-and-the-holding-company': {'sentiment': 'pos',
#   'z-score': -1.602253608083032},
#  'https://www.songkick.com/artists/242571-tiga': {'sentiment': 'pos',
#   'z-score': -0.9586485250922098},
#  'https://www.songkick.com/artists/48999-insane-clown-posse': {'sentiment': 'pos',
#   'z-score': -0.38988124244915734},
#  'https://www.songkick.com/artists/9725169-lennon-stella': {'sentiment': 'pos',
#   'z-score': 0.059145559637462916},
#  'https://www.songkick.com/artists/329262-cat-stevens': {'sentiment': 'pos',
#   'z-score': 1.8253176478448363},
#  'https://www.songkick.com/artists/2492321-mndr': {'sentiment': 'pos',
#   'z-score': -1.437610447317938},
#  'https://www.songkick.com/artists/671521-lisa-hannigan': {'sentiment': 'pos',
#   'z-score': 1.1368098846453514},
#  'https://www.songkick.com/artists/5628129-mozzy': {'sentiment': 'neg',
#   'z-score': -0.16394973399222842},
#  'https://www.songkick.com/artists/89047-aaron-lewis': {'sentiment': 'pos',
#   'z-score': 0.22378872040255715},
#  'https://www.songkick.com/artists/139921-ylvis': {'sentiment': 'pos',
#   'z-score': -1.33283752683106},
#  'https://www.songkick.com/artists/211157-joe-budden': {'sentiment': 'pos',
#   'z-score': -0.2102705216145095},
#  'https://www.songkick.com/artists/411960-cliff-richard': {'sentiment': 'pos',
#   'z-score': 0.5979777221414073},
#  'https://www.songkick.com/artists/560672-esperanza-spalding': {'sentiment': 'pos',
#   'z-score': 0.014242879428800849},
#  'https://www.songkick.com/artists/471496-barrington-levy': {'sentiment': 'pos',
#   'z-score': -0.33001100217094126},
#  'https://www.songkick.com/artists/511576-ringo-starr': {'sentiment': 'pos',
#   'z-score': -0.3749136823796033},
#  'https://www.songkick.com/artists/58137-tokio-hotel': {'sentiment': 'pos',
#   'z-score': 0.29862652075032686},
#  'https://www.songkick.com/artists/7990208-scott-bradlees-postmodern-jukebox': {'sentiment': 'pos',
#   'z-score': 0.5231399217936372},
#  'https://www.songkick.com/artists/175595-cool-kids': {'sentiment': 'pos',
#   'z-score': -1.572318487943924},
#  'https://www.songkick.com/artists/500641-deniece-williams': {'sentiment': 'pos',
#   'z-score': -0.1354327212667394},
#  'https://www.songkick.com/artists/5077118-bondax': {'sentiment': 'pos',
#   'z-score': -1.2579997264832898},
#  'https://www.songkick.com/artists/8685879-banners': {'sentiment': 'pos',
#   'z-score': 0.44830212144586706},
#  'https://www.songkick.com/artists/5257648-watsky': {'sentiment': 'pos',
#   'z-score': 0.2537238405416648},
#  'https://www.songkick.com/artists/7219274-kevin-morby': {'sentiment': 'pos',
#   'z-score': 0.5680426020022993},
#  'https://www.songkick.com/artists/132580-swans': {'sentiment': 'pos',
#   'z-score': -0.7640702441880075},
#  'https://www.songkick.com/artists/6941254-davido': {'sentiment': 'pos',
#   'z-score': 0.5231399217936372},
#  'https://www.songkick.com/artists/282481-markus-schulz': {'sentiment': 'pos',
#   'z-score': -0.5395568431446975},
#  'https://www.songkick.com/artists/2589501-small-black': {'sentiment': 'pos',
#   'z-score': -1.6621238483612482},
#  'https://www.songkick.com/artists/265425-los-fabulosos-cadillacs': {'sentiment': 'pos',
#   'z-score': 6.7346773506585516},
#  'https://www.songkick.com/artists/121990-jon-b': {'sentiment': 'pos',
#   'z-score': 0.6728155224891774},
#  'https://www.songkick.com/artists/135970-aaron-neville': {'sentiment': 'pos',
#   'z-score': 0.2537238405416648},
#  'https://www.songkick.com/artists/96319-fats-domino': {'sentiment': 'pos',
#   'z-score': -2.4404369719780568},
#  'https://www.songkick.com/artists/137873-genesis': {'sentiment': 'pos',
#   'z-score': -1.048453885509534},
#  'https://www.songkick.com/artists/537004-soko': {'sentiment': 'pos',
#   'z-score': -0.16536784140584743},
#  'https://www.songkick.com/artists/108446-shout-out-louds': {'sentiment': 'pos',
#   'z-score': -1.317869966761506},
#  'https://www.songkick.com/artists/5107583-blasterjaxx': {'sentiment': 'pos',
#   'z-score': -0.9586485250922098},
#  'https://www.songkick.com/artists/276806-hold-steady': {'sentiment': 'pos',
#   'z-score': -0.33001100217094126},
#  'https://www.songkick.com/artists/370878-kimya-dawson': {'sentiment': 'pos',
#   'z-score': -0.6443297636315757},
#  'https://www.songkick.com/artists/369656-joan-jett': {'sentiment': 'pos',
#   'z-score': 0.14895092005478705},
#  'https://www.songkick.com/artists/152978-riff-raff': {'sentiment': 'pos',
#   'z-score': -1.1681943660659662},
#  'https://www.songkick.com/artists/334240-foxy-brown': {'sentiment': 'pos',
#   'z-score': -0.38988124244915734},
#  'https://www.songkick.com/artists/344524-cary-brothers': {'sentiment': 'pos',
#   'z-score': -2.3506316115607326},
#  'https://www.songkick.com/artists/419200-bubba-sparxxx': {'sentiment': 'pos',
#   'z-score': -0.33001100217094126},
#  'https://www.songkick.com/artists/162315-set-it-off': {'sentiment': 'pos',
#   'z-score': 1.2266152450626755},
#  'https://www.songkick.com/artists/81719-kranium': {'sentiment': 'pos',
#   'z-score': 0.3285616408894349},
#  'https://www.songkick.com/artists/238957-tommy-james-and-the-shondells': {'sentiment': 'pos',
#   'z-score': -0.2402056417536171},
#  'https://www.songkick.com/artists/31437-rehab': {'sentiment': 'pos',
#   'z-score': 0.20882116033300313},
#  'https://www.songkick.com/artists/434993-men-without-hats': {'sentiment': 'pos',
#   'z-score': -0.6443297636315757},
#  'https://www.songkick.com/artists/498121-tony-toni-tone': {'sentiment': 'pos',
#   'z-score': 0.22378872040255715},
#  'https://www.songkick.com/artists/292381-10000-maniacs': {'sentiment': 'pos',
#   'z-score': 0.10404823984612498},
#  'https://www.songkick.com/artists/620826-maino': {'sentiment': 'pos',
#   'z-score': -1.03348632543998},
#  'https://www.songkick.com/artists/587119-we-were-promised-jetpacks': {'sentiment': 'pos',
#   'z-score': -0.6892324438402377},
#  'https://www.songkick.com/artists/60004-starting-line': {'sentiment': 'pos',
#   'z-score': -0.2701407618927252},
#  'https://www.songkick.com/artists/73100-tourist': {'sentiment': 'pos',
#   'z-score': -0.5694919632838056},
#  'https://www.songkick.com/artists/396691-matt-costa': {'sentiment': 'pos',
#   'z-score': -0.9586485250922098},
#  'https://www.songkick.com/artists/500479-fruit-bats': {'sentiment': 'pos',
#   'z-score': 0.5979777221414073},
#  'https://www.songkick.com/artists/2330488-steel-panther': {'sentiment': 'pos',
#   'z-score': 0.4632696815154211},
#  'https://www.songkick.com/artists/5453373-chris-malinchak': {'sentiment': 'pos',
#   'z-score': -1.2430321664137358},
#  'https://www.songkick.com/artists/303079-john-michael-montgomery': {'sentiment': 'pos',
#   'z-score': -0.2252380816840635},
#  'https://www.songkick.com/artists/577118-orianthi': {'sentiment': 'pos',
#   'z-score': 0.5830101620718533},
#  'https://www.songkick.com/artists/492794-jedi-mind-tricks': {'sentiment': 'pos',
#   'z-score': 0.1788860401938951},
#  'https://www.songkick.com/artists/404702-steve-vai': {'sentiment': 'pos',
#   'z-score': -0.060594920918969265},
#  'https://www.songkick.com/artists/207026-mew': {'sentiment': 'pos',
#   'z-score': 0.44830212144586706},
#  'https://www.songkick.com/artists/244427-desire': {'sentiment': 'pos',
#   'z-score': -1.078389005648642},
#  'https://www.songkick.com/artists/9242614-omar-apollo': {'sentiment': 'pos',
#   'z-score': 0.8973289235324877},
#  'https://www.songkick.com/artists/492456-sisters-of-mercy': {'sentiment': 'pos',
#   'z-score': -0.4198163625882654},
#  'https://www.songkick.com/artists/541506-taj-mahal': {'sentiment': 'pos',
#   'z-score': 0.5979777221414073},
#  'https://www.songkick.com/artists/9215514-hobo-johnson': {'sentiment': 'pos',
#   'z-score': 1.1517774447149054},
#  'https://www.songkick.com/artists/3356916-sublime-with-rome': {'sentiment': 'pos',
#   'z-score': 0.5530750419327453},
#  'https://www.songkick.com/artists/595798-punch-brothers': {'sentiment': 'pos',
#   'z-score': -0.7790378042575615},
#  'https://www.songkick.com/artists/1959719-goldroom': {'sentiment': 'pos',
#   'z-score': 0.13398335998523303},
#  'https://www.songkick.com/artists/1068319-konshens': {'sentiment': 'pos',
#   'z-score': -0.5096217230055895},
#  'https://www.songkick.com/artists/430327-expendables': {'sentiment': 'pos',
#   'z-score': -0.2102705216145095},
#  'https://www.songkick.com/artists/369534-technotronic': {'sentiment': 'pos',
#   'z-score': -0.9287134049531017},
#  'https://www.songkick.com/artists/7013269-mild-high-club': {'sentiment': 'pos',
#   'z-score': 0.6279128422805154},
#  'https://www.songkick.com/artists/541274-tito-el-bambino': {'sentiment': 'pos',
#   'z-score': -0.4497514827273734},
#  'https://www.songkick.com/artists/6636479-del-the-funky-homosapien': {'sentiment': 'pos',
#   'z-score': -0.7341351240488995},
#  'https://www.songkick.com/artists/452089-albert-hammond-jr': {'sentiment': 'pos',
#   'z-score': -0.3599461223100493},
#  'https://www.songkick.com/artists/460744-devotchka': {'sentiment': 'pos',
#   'z-score': 0.044177999567908896},
#  'https://www.songkick.com/artists/5934149-lion-babe': {'sentiment': 'pos',
#   'z-score': 2.5736956513225366},
#  'https://www.songkick.com/artists/416972-souls-of-mischief': {'sentiment': 'pos',
#   'z-score': -1.8117994490567881},
#  'https://www.songkick.com/artists/8633909-blac-youngsta': {'sentiment': 'pos',
#   'z-score': 0.4632696815154211},
#  'https://www.songkick.com/artists/6008179-judah-and-the-lion': {'sentiment': 'pos',
#   'z-score': 0.8973289235324877},
#  'https://www.songkick.com/artists/2874581-active-child': {'sentiment': 'pos',
#   'z-score': -0.9436809650226557},
#  'https://www.songkick.com/artists/411643-yardbirds': {'sentiment': 'pos',
#   'z-score': 0.403399441237205},
#  'https://www.songkick.com/artists/6126864-laura-mvula': {'sentiment': 'pos',
#   'z-score': 0.1938536002634491},
#  'https://www.songkick.com/artists/436921-sounds': {'sentiment': 'pos',
#   'z-score': -1.1382592459268581},
#  'https://www.songkick.com/artists/8698453-ghostemane': {'sentiment': 'pos',
#   'z-score': 1.032036964158473},
#  'https://www.songkick.com/artists/6092694-empress-of': {'sentiment': 'pos',
#   'z-score': -0.6293622035620217},
#  'https://www.songkick.com/artists/302453-gretchen-wilson': {'sentiment': 'pos',
#   'z-score': -0.2701407618927252},
#  'https://www.songkick.com/artists/92437-church': {'sentiment': 'pos',
#   'z-score': -0.16536784140584743},
#  'https://www.songkick.com/artists/308960-beth-orton': {'sentiment': 'pos',
#   'z-score': -0.5844595233533596},
#  'https://www.songkick.com/artists/6519554-chronixx': {'sentiment': 'pos',
#   'z-score': 0.957199163810703},
#  'https://www.songkick.com/artists/128679-troggs': {'sentiment': 'pos',
#   'z-score': -0.12046516119718535},
#  'https://www.songkick.com/artists/172923-sin-bandera': {'sentiment': 'pos',
#   'z-score': -0.7790378042575615},
#  'https://www.songkick.com/artists/428361-los-enanitos-verdes': {'sentiment': 'pos',
#   'z-score': -0.5545244032142516},
#  'https://www.songkick.com/artists/4035406-kishi-bashi': {'sentiment': 'pos',
#   'z-score': 0.7925560030456096},
#  'https://www.songkick.com/artists/178178-sergio-mendes': {'sentiment': 'pos',
#   'z-score': -0.3000758820318332},
#  'https://www.songkick.com/artists/430648-average-white-band': {'sentiment': 'pos',
#   'z-score': -0.38988124244915734},
#  'https://www.songkick.com/artists/1646231-sidney-samson': {'sentiment': 'pos',
#   'z-score': -1.1532268059964121},
#  'https://www.songkick.com/artists/352787-black-star': {'sentiment': 'pos',
#   'z-score': -1.5124482476657082},
#  'https://www.songkick.com/artists/7736334-lookas': {'sentiment': 'pos',
#   'z-score': 1.675642047149296},
#  'https://www.songkick.com/artists/324048-liz-phair': {'sentiment': 'pos',
#   'z-score': -1.317869966761506},
#  'https://www.songkick.com/artists/507341-roy-ayers': {'sentiment': 'pos',
#   'z-score': -0.8987782848139937},
#  'https://www.songkick.com/artists/5960099-tujamo': {'sentiment': 'pos',
#   'z-score': -0.6592973237011297},
#  'https://www.songkick.com/artists/518799-p-diddy': {'sentiment': 'pos',
#   'z-score': 0.403399441237205},
#  'https://www.songkick.com/artists/158971-fisher': {'sentiment': 'pos',
#   'z-score': -2.1859884507956386},
#  'https://www.songkick.com/artists/44903-paula-abdul': {'sentiment': 'pos',
#   'z-score': 0.1938536002634491},
#  'https://www.songkick.com/artists/3349566-carla-morrison': {'sentiment': 'pos',
#   'z-score': -0.16536784140584743},
#  'https://www.songkick.com/artists/481340-joanna-newsom': {'sentiment': 'pos',
#   'z-score': -0.10549760112763133},
#  'https://www.songkick.com/artists/313896-nneka': {'sentiment': 'pos',
#   'z-score': -0.47968660286648146},
#  'https://www.songkick.com/artists/87912-testament': {'sentiment': 'pos',
#   'z-score': -0.19530296154495547},
#  'https://www.songkick.com/artists/466296-moon-taxi': {'sentiment': 'pos',
#   'z-score': -0.7191675639793454},
#  'https://www.songkick.com/artists/1066226-quintino': {'sentiment': 'pos',
#   'z-score': -1.1382592459268581},
#  'https://www.songkick.com/artists/543537-david-bisbal': {'sentiment': 'pos',
#   'z-score': 0.044177999567908896},
#  'https://www.songkick.com/artists/522128-love-and-theft': {'sentiment': 'pos',
#   'z-score': -0.7341351240488995},
#  'https://www.songkick.com/artists/163316-level-42': {'sentiment': 'pos',
#   'z-score': 0.16391848012434107},
#  'https://www.songkick.com/artists/355348-pond': {'sentiment': 'pos',
#   'z-score': -0.9436809650226557},
#  'https://www.songkick.com/artists/481518-rose-royce': {'sentiment': 'pos',
#   'z-score': 0.044177999567908896},
#  'https://www.songkick.com/artists/937055-chuckie': {'sentiment': 'pos',
#   'z-score': -0.9736160851617638},
#  'https://www.songkick.com/artists/499365-cowboy-junkies': {'sentiment': 'pos',
#   'z-score': -0.0007246806407531735},
#  'https://www.songkick.com/artists/9280609-lovelytheband': {'sentiment': 'pos',
#   'z-score': 1.7654474075666202},
#  'https://www.songkick.com/artists/457177-bob-moses': {'sentiment': 'pos',
#   'z-score': 1.61577180687108},
#  'https://www.songkick.com/artists/189580-tarrus-riley': {'sentiment': 'pos',
#   'z-score': 0.2537238405416648},
#  'https://www.songkick.com/artists/9506759-queen-naija': {'sentiment': 'pos',
#   'z-score': 1.660674487079742},
#  'https://www.songkick.com/artists/1050031-frankie-ballard': {'sentiment': 'pos',
#   'z-score': 0.8075235631151636},
#  'https://www.songkick.com/artists/9258529-rico-nasty': {'sentiment': 'pos',
#   'z-score': -0.10549760112763133},
#  'https://www.songkick.com/artists/1055569-atlas-sound': {'sentiment': 'neg',
#   'z-score': -0.5570233421715841},
#  'https://www.songkick.com/artists/297652-hellyeah': {'sentiment': 'pos',
#   'z-score': 1.017069404088919},
#  'https://www.songkick.com/artists/14576-sammie': {'sentiment': 'neg',
#   'z-score': -0.4155168432270161},
#  'https://www.songkick.com/artists/250442-dj-premier': {'sentiment': 'pos',
#   'z-score': -1.2280646063441818},
#  'https://www.songkick.com/artists/368227-trisha-yearwood': {'sentiment': 'pos',
#   'z-score': 0.6877830825587314},
#  'https://www.songkick.com/artists/399640-savage': {'sentiment': 'pos',
#   'z-score': -1.4974806875961542},
#  'https://www.songkick.com/artists/365453-soul-ii-soul': {'sentiment': 'pos',
#   'z-score': -0.7042000039097918},
#  'https://www.songkick.com/artists/5738909-piso-21': {'sentiment': 'pos',
#   'z-score': 0.1938536002634491},
#  'https://www.songkick.com/artists/217917-meshuggah': {'sentiment': 'neg',
#   'z-score': 0.21340092985995293},
#  'https://www.songkick.com/artists/238833-hatebreed': {'sentiment': 'pos',
#   'z-score': 0.16391848012434107},
#  'https://www.songkick.com/artists/3678466-austra': {'sentiment': 'pos',
#   'z-score': 0.4932048016545291},
#  'https://www.songkick.com/artists/6580009-alex-aiono': {'sentiment': 'pos',
#   'z-score': 2.5437605311834286},
#  'https://www.songkick.com/artists/315745-king-crimson': {'sentiment': 'pos',
#   'z-score': -0.6742648837706837},
#  'https://www.songkick.com/artists/36875-hooverphonic': {'sentiment': 'pos',
#   'z-score': 0.6877830825587314},
#  'https://www.songkick.com/artists/1350103-bassjackers': {'sentiment': 'pos',
#   'z-score': -1.2130970462746278},
#  'https://www.songkick.com/artists/369590-los-campesinos': {'sentiment': 'pos',
#   'z-score': 1.032036964158473},
#  'https://www.songkick.com/artists/4515978-jungle-giants': {'sentiment': 'pos',
#   'z-score': 1.1368098846453514},
#  'https://www.songkick.com/artists/368829-procol-harum': {'sentiment': 'pos',
#   'z-score': -0.9137458448835477},
#  'https://www.songkick.com/artists/5319013-brothers-osborne': {'sentiment': 'pos',
#   'z-score': 1.1966801249235675},
#  'https://www.songkick.com/artists/8538309-steve-lacy': {'sentiment': 'pos',
#   'z-score': 1.4810637662450938},
#  'https://www.songkick.com/artists/248308-liam-gallagher': {'sentiment': 'pos',
#   'z-score': 0.7626208829065015},
#  'https://www.songkick.com/artists/356341-bill-evans': {'sentiment': 'pos',
#   'z-score': -1.377740207039722},
#  'https://www.songkick.com/artists/125118-leon': {'sentiment': 'pos',
#   'z-score': 0.28365896068077284},
#  'https://www.songkick.com/artists/24672-raheem-devaughn': {'sentiment': 'pos',
#   'z-score': 0.4932048016545291},
#  'https://www.songkick.com/artists/6459474-bethel-music': {'sentiment': 'pos',
#   'z-score': 1.2116476849931215},
#  'https://www.songkick.com/artists/4111601-dan-croll': {'sentiment': 'pos',
#   'z-score': -0.04562736084941524},
#  'https://www.songkick.com/artists/200182-issues': {'sentiment': 'pos',
#   'z-score': 0.8823613634629337},
#  'https://www.songkick.com/artists/365822-clint-mansell': {'sentiment': 'pos',
#   'z-score': -0.7191675639793454},
#  'https://www.songkick.com/artists/9046429-noah-kahan': {'sentiment': 'pos',
#   'z-score': 1.3014530454104456},
#  'https://www.songkick.com/artists/459454-paul-young': {'sentiment': 'pos',
#   'z-score': -0.19530296154495547},
#  'https://www.songkick.com/artists/9541014-mxmtoon': {'sentiment': 'pos',
#   'z-score': 0.9871342839498111},
#  'https://www.songkick.com/artists/436645-futuristic': {'sentiment': 'pos',
#   'z-score': 1.6906096072188501},
#  'https://www.songkick.com/artists/5229883-jana-kramer': {'sentiment': 'pos',
#   'z-score': 0.5381074818631912},
#  'https://www.songkick.com/artists/385112-mr-vegas': {'sentiment': 'pos',
#   'z-score': 0.14895092005478705},
#  'https://www.songkick.com/artists/412257-grand-funk-railroad': {'sentiment': 'pos',
#   'z-score': 0.43333456137631304},
#  'https://www.songkick.com/artists/207096-lyfe-jennings': {'sentiment': 'pos',
#   'z-score': -0.6742648837706837},
#  'https://www.songkick.com/artists/214626-pharoahe-monch': {'sentiment': 'pos',
#   'z-score': 0.35849676102854294},
#  'https://www.songkick.com/artists/8521038-hey-violet': {'sentiment': 'pos',
#   'z-score': 0.942231603741149},
#  'https://www.songkick.com/artists/210525-michael-w-smith': {'sentiment': 'pos',
#   'z-score': 1.8851878881230515},
#  'https://www.songkick.com/artists/312457-night-ranger': {'sentiment': 'pos',
#   'z-score': 0.5830101620718533},
#  'https://www.songkick.com/artists/442534-grits': {'sentiment': 'pos',
#   'z-score': -1.5124482476657082},
#  'https://www.songkick.com/artists/34817-noisia': {'sentiment': 'pos',
#   'z-score': -1.302902406691952},
#  'https://www.songkick.com/artists/6594214-frankie-cosmos': {'sentiment': 'pos',
#   'z-score': -0.1354327212667394},
#  'https://www.songkick.com/artists/8435978-daniela-andrade': {'sentiment': 'pos',
#   'z-score': -0.04562736084941524},
#  'https://www.songkick.com/artists/1019030-colt-ford': {'sentiment': 'pos',
#   'z-score': 0.8374586832542716},
#  'https://www.songkick.com/artists/3601896-com-truise': {'sentiment': 'pos',
#   'z-score': -0.9885836452313178},
#  'https://www.songkick.com/artists/7120994-yung-lean': {'sentiment': 'pos',
#   'z-score': -0.5096217230055895},
#  'https://www.songkick.com/artists/241996-midnight-oil': {'sentiment': 'pos',
#   'z-score': 0.9871342839498111},
#  'https://www.songkick.com/artists/8395978-jauz': {'sentiment': 'pos',
#   'z-score': 0.5231399217936372},
#  'https://www.songkick.com/artists/116729-asgeir': {'sentiment': 'pos',
#   'z-score': 0.16391848012434107},
#  'https://www.songkick.com/artists/551737-marc-cohn': {'sentiment': 'pos',
#   'z-score': 1.4660962061755398},
#  'https://www.songkick.com/artists/5384948-claptone': {'sentiment': 'pos',
#   'z-score': -0.8389080445357776},
#  'https://www.songkick.com/artists/6138739-wafia': {'sentiment': 'pos',
#   'z-score': 0.1788860401938951},
#  'https://www.songkick.com/artists/8926399-saint-jhn': {'sentiment': 'pos',
#   'z-score': -1.6321887282221401},
#  'https://www.songkick.com/artists/127688-verve-pipe': {'sentiment': 'pos',
#   'z-score': 0.5830101620718533},
#  'https://www.songkick.com/artists/506999-langhorne-slim': {'sentiment': 'pos',
#   'z-score': 0.8524262433238257},
#  'https://www.songkick.com/artists/3822376-phoebe-bridgers': {'sentiment': 'pos',
#   'z-score': 0.43333456137631304},
#  'https://www.songkick.com/artists/9292764-prettymuch': {'sentiment': 'pos',
#   'z-score': 0.8973289235324877},
#  'https://www.songkick.com/artists/8335548-verite': {'sentiment': 'pos',
#   'z-score': 3.247235854452467},
#  'https://www.songkick.com/artists/74079-dilated-peoples': {'sentiment': 'pos',
#   'z-score': -0.2851083219622792},
#  'https://www.songkick.com/artists/394243-bones': {'sentiment': 'pos',
#   'z-score': -0.9436809650226557},
#  'https://www.songkick.com/artists/2615541-havana-brown': {'sentiment': 'pos',
#   'z-score': -1.587286048013478},
#  'https://www.songkick.com/artists/8913064-dodie': {'sentiment': 'pos',
#   'z-score': 1.1966801249235675},
#  'https://www.songkick.com/artists/257019-kevin-lyttle': {'sentiment': 'pos',
#   'z-score': -1.078389005648642},
#  'https://www.songkick.com/artists/568890-pop-evil': {'sentiment': 'pos',
#   'z-score': 0.7027506426282855},
#  'https://www.songkick.com/artists/331296-antiflag': {'sentiment': 'pos',
#   'z-score': 0.972166723880257},
#  'https://www.songkick.com/artists/272856-brother-ali': {'sentiment': 'pos',
#   'z-score': 0.8075235631151636},
#  'https://www.songkick.com/artists/6387054-kat-dahlia': {'sentiment': 'pos',
#   'z-score': 0.20882116033300313},
#  'https://www.songkick.com/artists/436024-colin-hay': {'sentiment': 'pos',
#   'z-score': 0.942231603741149},
#  'https://www.songkick.com/artists/6140284-sturgill-simpson': {'sentiment': 'pos',
#   'z-score': -1.093356565718196},
#  'https://www.songkick.com/artists/1173280-classixx': {'sentiment': 'pos',
#   'z-score': -1.6770914084308022},
#  'https://www.songkick.com/artists/112342-kidz-bop-kids': {'sentiment': 'pos',
#   'z-score': -2.1111506504478688},
#  'https://www.songkick.com/artists/226352-driveby-truckers': {'sentiment': 'pos',
#   'z-score': 0.5680426020022993},
#  'https://www.songkick.com/artists/466850-richard-ashcroft': {'sentiment': 'pos',
#   'z-score': -0.07556248098852328},
#  'https://www.songkick.com/artists/898755-britt-nicole': {'sentiment': 'pos',
#   'z-score': -0.4347839226578194},
#  'https://www.songkick.com/artists/353458-gogos': {'sentiment': 'pos',
#   'z-score': -0.3599461223100493},
# ...
#  'https://www.songkick.com/artists/414567-jose-feliciano': {'sentiment': 'pos',
#   'z-score': -0.09053004105807731},
#  'https://www.songkick.com/artists/165747-against-me': {'sentiment': 'pos',
#   'z-score': 0.35849676102854294},
#  'https://www.songkick.com/artists/483788-natalia-lafourcade': {'sentiment': 'pos',
#   'z-score': -0.060594920918969265},
#  'https://www.songkick.com/artists/125134-cutting-crew': {'sentiment': 'pos',
#   'z-score': -1.1681943660659662},
#  'https://www.songkick.com/artists/434434-luis-miguel': {'sentiment': 'pos',
#   'z-score': -0.5694919632838056},
#  'https://www.songkick.com/artists/6227099-dj-mustard': {'sentiment': 'pos',
#   'z-score': -1.048453885509534},
#  'https://www.songkick.com/artists/16865-ladytron': {'sentiment': 'pos',
#   'z-score': -0.8089729243966696},
#  'https://www.songkick.com/artists/381134-snap': {'sentiment': 'pos',
#   'z-score': -1.1681943660659662},
#  'https://www.songkick.com/artists/94949-mystikal': {'sentiment': 'pos',
#   'z-score': -0.1354327212667394},
#  'https://www.songkick.com/artists/17607-cute-is-what-we-aim-for': {'sentiment': 'pos',
#   'z-score': 0.059145559637462916},
#  'https://www.songkick.com/artists/268834-gary-jules': {'sentiment': 'pos',
#   'z-score': -1.78186432891768},
#  'https://www.songkick.com/artists/39576-queensryche': {'sentiment': 'pos',
#   'z-score': 0.29862652075032686},
#  'https://www.songkick.com/artists/478572-philip-glass': {'sentiment': 'pos',
#   'z-score': -0.46471904279692744},
#  'https://www.songkick.com/artists/4962083-car-seat-headrest': {'sentiment': 'pos',
#   'z-score': -0.09053004105807731},
#  'https://www.songkick.com/artists/305645-ferry-corsten': {'sentiment': 'pos',
#   'z-score': 0.942231603741149},
#  'https://www.songkick.com/artists/199583-craig-morgan': {'sentiment': 'pos',
#   'z-score': -0.060594920918969265},
#  'https://www.songkick.com/artists/443638-soja': {'sentiment': 'pos',
#   'z-score': 0.35849676102854294},
#  'https://www.songkick.com/artists/325199-berlin': {'sentiment': 'pos',
#   'z-score': -1.617221168152586},
#  'https://www.songkick.com/artists/240231-xavier-rudd': {'sentiment': 'pos',
#   'z-score': 1.5109988863842019},
#  'https://www.songkick.com/artists/153795-infected-mushroom': {'sentiment': 'pos',
#   'z-score': -0.5844595233533596},
#  'https://www.songkick.com/artists/560517-elvis-crespo': {'sentiment': 'pos',
#   'z-score': 0.29862652075032686},
#  'https://www.songkick.com/artists/248578-yelle': {'sentiment': 'pos',
#   'z-score': 0.5530750419327453},
#  'https://www.songkick.com/artists/232412-joe-jackson': {'sentiment': 'pos',
#   'z-score': -0.10549760112763133},
#  'https://www.songkick.com/artists/2203311-ruel': {'sentiment': 'pos',
#   'z-score': 0.388431881167651},
#  'https://www.songkick.com/artists/519672-donell-jones': {'sentiment': 'pos',
#   'z-score': -0.5395568431446975},
#  'https://www.songkick.com/artists/460417-jodeci': {'sentiment': 'pos',
#   'z-score': -0.16536784140584743},
#  'https://www.songkick.com/artists/109675-senses-fail': {'sentiment': 'pos',
#   'z-score': -0.4497514827273734},
#  'https://www.songkick.com/artists/220385-crystal-method': {'sentiment': 'pos',
#   'z-score': -1.078389005648642},
#  'https://www.songkick.com/artists/804395-dash-berlin': {'sentiment': 'pos',
#   'z-score': -1.33283752683106},
#  'https://www.songkick.com/artists/2554951-family-of-the-year': {'sentiment': 'pos',
#   'z-score': -0.8538756046053316},
#  'https://www.songkick.com/artists/124651-alejandro-fernandez': {'sentiment': 'pos',
#   'z-score': -0.2851083219622792},
#  'https://www.songkick.com/artists/5872269-piano-guys': {'sentiment': 'pos',
#   'z-score': 2.3042795700705643},
#  'https://www.songkick.com/artists/205808-funkadelic': {'sentiment': 'pos',
#   'z-score': -0.2102705216145095},
#  'https://www.songkick.com/artists/7858599-rainbow-kitten-surprise': {'sentiment': 'pos',
#   'z-score': 1.9151230082621595},
#  'https://www.songkick.com/artists/109541-jim-jones': {'sentiment': 'pos',
#   'z-score': -0.9287134049531017},
#  'https://www.songkick.com/artists/8258588-seinabo-sey': {'sentiment': 'pos',
#   'z-score': 0.35849676102854294},
#  'https://www.songkick.com/artists/337767-emmylou-harris': {'sentiment': 'pos',
#   'z-score': -0.6892324438402377},
#  'https://www.songkick.com/artists/522636-gunit': {'sentiment': 'pos',
#   'z-score': -1.078389005648642},
#  'https://www.songkick.com/artists/124334-jaheim': {'sentiment': 'pos',
#   'z-score': -1.1981294862050738},
#  'https://www.songkick.com/artists/370226-grace-jones': {'sentiment': 'pos',
#   'z-score': -0.7341351240488995},
#  'https://www.songkick.com/artists/146059-smokey-robinson': {'sentiment': 'pos',
#   'z-score': 0.7476533228369475},
#  'https://www.songkick.com/artists/14400-blitzen-trapper': {'sentiment': 'pos',
#   'z-score': 0.08908067977657096},
#  'https://www.songkick.com/artists/1057184-pleasure-p': {'sentiment': 'pos',
#   'z-score': -0.07556248098852328},
#  'https://www.songkick.com/artists/520156-gary-numan': {'sentiment': 'pos',
#   'z-score': -0.060594920918969265},
#  'https://www.songkick.com/artists/2480126-red': {'sentiment': 'pos',
#   'z-score': -1.1382592459268581},
#  'https://www.songkick.com/artists/3294396-joywave': {'sentiment': 'pos',
#   'z-score': 0.044177999567908896},
#  'https://www.songkick.com/artists/556981-jeremy-camp': {'sentiment': 'pos',
#   'z-score': 1.4511286461059858},
#  'https://www.songkick.com/artists/518697-story-of-the-year': {'sentiment': 'pos',
#   'z-score': -1.4675455674570461},
#  'https://www.songkick.com/artists/4249456-haley-reinhart': {'sentiment': 'pos',
#   'z-score': -1.048453885509534},
#  'https://www.songkick.com/artists/245404-lucinda-williams': {'sentiment': 'pos',
#   'z-score': 0.1938536002634491},
#  'https://www.songkick.com/artists/8980149-maggie-lindemann': {'sentiment': 'pos',
#   'z-score': -1.003551205300872},
#  'https://www.songkick.com/artists/553724-less-than-jake': {'sentiment': 'pos',
#   'z-score': 0.418367001306759},
#  'https://www.songkick.com/artists/2628296-k-michelle': {'sentiment': 'pos',
#   'z-score': 0.07411311970701694},
#  'https://www.songkick.com/artists/515856-ween': {'sentiment': 'pos',
#   'z-score': -0.1354327212667394},
#  'https://www.songkick.com/artists/522373-jkwon': {'sentiment': 'pos',
#   'z-score': -1.9315399296132203},
#  'https://www.songkick.com/artists/451245-hot-chocolate': {'sentiment': 'pos',
#   'z-score': -0.47968660286648146},
#  'https://www.songkick.com/artists/8542674-wet': {'sentiment': 'pos',
#   'z-score': 0.5979777221414073},
#  'https://www.songkick.com/artists/4311036-death-grips': {'sentiment': 'pos',
#   'z-score': -1.048453885509534},
#  'https://www.songkick.com/artists/432351-death-from-above-1979': {'sentiment': 'pos',
#   'z-score': -0.6892324438402377},
#  'https://www.songkick.com/artists/109247-trick-daddy': {'sentiment': 'pos',
#   'z-score': -2.0213452900305446},
#  'https://www.songkick.com/artists/280948-sevendust': {'sentiment': 'pos',
#   'z-score': 1.1218423245757974},
#  'https://www.songkick.com/artists/7898084-greta-van-fleet': {'sentiment': 'pos',
#   'z-score': 0.2537238405416648},
#  'https://www.songkick.com/artists/266145-krsone': {'sentiment': 'pos',
#   'z-score': 0.11901579991567901},
#  'https://www.songkick.com/artists/9254044-karol-g': {'sentiment': 'pos',
#   'z-score': 0.957199163810703},
#  'https://www.songkick.com/artists/591126-miami-horror': {'sentiment': 'pos',
#   'z-score': 0.059145559637462916},
#  'https://www.songkick.com/artists/100744-three-dog-night': {'sentiment': 'pos',
#   'z-score': 0.6428804023500694},
#  'https://www.songkick.com/artists/4364228-bryce-vine': {'sentiment': 'pos',
#   'z-score': 2.4689227308356583},
#  'https://www.songkick.com/artists/73962-suzanne-vega': {'sentiment': 'pos',
#   'z-score': 0.5081723617240832},
#  'https://www.songkick.com/artists/512923-black-label-society': {'sentiment': 'pos',
#   'z-score': 0.7626208829065015},
#  'https://www.songkick.com/artists/398921-alexi-murdoch': {'sentiment': 'pos',
#   'z-score': -1.123291685857304},
#  'https://www.songkick.com/artists/603864-caravan-palace': {'sentiment': 'pos',
#   'z-score': 0.2686914006112188},
#  'https://www.songkick.com/artists/517398-edwin-mccain': {'sentiment': 'pos',
#   'z-score': 1.6906096072188501},
#  'https://www.songkick.com/artists/379068-david-cook': {'sentiment': 'pos',
#   'z-score': 0.7476533228369475},
#  'https://www.songkick.com/artists/512068-presets': {'sentiment': 'pos',
#   'z-score': 0.5979777221414073},
#  'https://www.songkick.com/artists/9593889-ybn-cordae': {'sentiment': 'pos',
#   'z-score': -0.10549760112763133},
#  'https://www.songkick.com/artists/119191-fine-young-cannibals': {'sentiment': 'pos',
#   'z-score': -0.7640702441880075},
#  'https://www.songkick.com/artists/1058677-dom-kennedy': {'sentiment': 'pos',
#   'z-score': -0.8688431646748856},
#  'https://www.songkick.com/artists/225795-charlatans': {'sentiment': 'pos',
#   'z-score': -1.347805086900614},
#  'https://www.songkick.com/artists/488253-mountain-goats': {'sentiment': 'pos',
#   'z-score': 0.044177999567908896},
#  'https://www.songkick.com/artists/450159-madeleine-peyroux': {'sentiment': 'pos',
#   'z-score': 0.4632696815154211},
#  'https://www.songkick.com/artists/2562891-surfer-blood': {'sentiment': 'pos',
#   'z-score': 0.37346432109809696},
#  'https://www.songkick.com/artists/6878929-smallpools': {'sentiment': 'pos',
#   'z-score': 0.3135940808198809},
#  'https://www.songkick.com/artists/71013-kurupt': {'sentiment': 'neg',
#   'z-score': -0.44696273188136454},
#  'https://www.songkick.com/artists/1089106-sheppard': {'sentiment': 'pos',
#   'z-score': 0.6129452822109613},
#  'https://www.songkick.com/artists/224609-badly-drawn-boy': {'sentiment': 'pos',
#   'z-score': -0.3599461223100493},
#  'https://www.songkick.com/artists/59359-calexico': {'sentiment': 'pos',
#   'z-score': 0.5081723617240832},
#  'https://www.songkick.com/artists/4516073-skizzy-mars': {'sentiment': 'pos',
#   'z-score': 0.23875628047211075},
#  'https://www.songkick.com/artists/9562259-trevor-powers': {'sentiment': 'pos',
#   'z-score': 0.5381074818631912},
#  'https://www.songkick.com/artists/582704-blessthefall': {'sentiment': 'pos',
#   'z-score': 0.1788860401938951},
#  'https://www.songkick.com/artists/9089679-wallows': {'sentiment': 'pos',
#   'z-score': 1.3912584058277697},
#  'https://www.songkick.com/artists/186546-ghost': {'sentiment': 'pos',
#   'z-score': -0.060594920918969265},
#  'https://www.songkick.com/artists/425861-coin': {'sentiment': 'pos',
#   'z-score': 1.5109988863842019},
#  'https://www.songkick.com/artists/3324291-roscoe-dash': {'sentiment': 'pos',
#   'z-score': -0.8089729243966696},
#  'https://www.songkick.com/artists/964551-ty-segall': {'sentiment': 'pos',
#   'z-score': 0.16391848012434107},
#  'https://www.songkick.com/artists/157182-crazy-town': {'sentiment': 'pos',
#   'z-score': 0.014242879428800849},
#  'https://www.songkick.com/artists/4665043-mike-stud': {'sentiment': 'pos',
#   'z-score': -0.6143946434924676},
#  'https://www.songkick.com/artists/505398-camila': {'sentiment': 'pos',
#   'z-score': 0.44830212144586706},
#  'https://www.songkick.com/artists/7214-hanson': {'sentiment': 'pos',
#   'z-score': 0.8374586832542716},
#  'https://www.songkick.com/artists/258567-dionne-warwick': {'sentiment': 'pos',
#   'z-score': 0.08908067977657096},
#  'https://www.songkick.com/artists/308667-goldfinger': {'sentiment': 'pos',
#   'z-score': -0.9885836452313178},
#  'https://www.songkick.com/artists/186299-harry-connick-jr': {'sentiment': 'pos',
#   'z-score': -1.018518765370426},
#  'https://www.songkick.com/artists/709326-gallant': {'sentiment': 'pos',
#   'z-score': 0.972166723880257},
#  'https://www.songkick.com/artists/5442918-diiv': {'sentiment': 'pos',
#   'z-score': 0.5231399217936372},
#  'https://www.songkick.com/artists/4517963-seven-lions': {'sentiment': 'pos',
#   'z-score': 0.5530750419327453},
#  'https://www.songkick.com/artists/498484-paul-oakenfold': {'sentiment': 'pos',
#   'z-score': -0.1504002813362934},
#  'https://www.songkick.com/artists/83627-danzig': {'sentiment': 'pos',
#   'z-score': -0.6443297636315757},
#  'https://www.songkick.com/artists/9701784-megan-thee-stallion': {'sentiment': 'pos',
#   'z-score': -2.141085770586977},
#  'https://www.songkick.com/artists/109857-pepper': {'sentiment': 'pos',
#   'z-score': 0.37346432109809696},
#  'https://www.songkick.com/artists/2503041-w-and-w': {'sentiment': 'pos',
#   'z-score': 0.7775884429760556},
#  'https://www.songkick.com/artists/547454-blonde-redhead': {'sentiment': 'pos',
#   'z-score': 0.2686914006112188},
#  'https://www.songkick.com/artists/380631-new-edition': {'sentiment': 'pos',
#   'z-score': 0.6129452822109613},
#  'https://www.songkick.com/artists/7507524-loyle-carner': {'sentiment': 'pos',
#   'z-score': 1.9151230082621595},
#  'https://www.songkick.com/artists/478934-benny-sings': {'sentiment': 'pos',
#   'z-score': -0.18033540147540145},
#  'https://www.songkick.com/artists/200809-queen-latifah': {'sentiment': 'pos',
#   'z-score': -0.6592973237011297},
#  'https://www.songkick.com/artists/429998-mk': {'sentiment': 'pos',
#   'z-score': -1.1681943660659662},
#  'https://www.songkick.com/artists/707825-aesop-rock': {'sentiment': 'pos',
#   'z-score': 0.28365896068077284},
#  'https://www.songkick.com/artists/103990-montgomery-gentry': {'sentiment': 'pos',
#   'z-score': -0.2102705216145095},
#  'https://www.songkick.com/artists/67100-built-to-spill': {'sentiment': 'pos',
#   'z-score': 0.07411311970701694},
#  'https://www.songkick.com/artists/174854-motorhead': {'sentiment': 'pos',
#   'z-score': -1.1981294862050738},
#  'https://www.songkick.com/artists/497389-biz-markie': {'sentiment': 'pos',
#   'z-score': -1.1831619261355197},
#  'https://www.songkick.com/artists/8796259-sofi-tukker': {'sentiment': 'pos',
#   'z-score': 1.8702203280534975},
#  'https://www.songkick.com/artists/25109-sigrid': {'sentiment': 'pos',
#   'z-score': 2.4539551707661045},
#  'https://www.songkick.com/artists/177289-spinners': {'sentiment': 'pos',
#   'z-score': 0.4632696815154211},
#  'https://www.songkick.com/artists/520157-newsboys': {'sentiment': 'pos',
#   'z-score': 1.1817125648540134},
#  'https://www.songkick.com/artists/451901-carla-bruni': {'sentiment': 'pos',
#   'z-score': -1.1532268059964121},
#  'https://www.songkick.com/artists/9555444-king-princess': {'sentiment': 'pos',
#   'z-score': 2.244409329792348},
#  'https://www.songkick.com/artists/1061208-nils-frahm': {'sentiment': 'pos',
#   'z-score': 0.08908067977657096},
#  'https://www.songkick.com/artists/218428-stooges': {'sentiment': 'pos',
#   'z-score': -1.766896768848126},
#  'https://www.songkick.com/artists/786955-rosalia': {'sentiment': 'pos',
#   'z-score': -0.40484880251871136},
#  'https://www.songkick.com/artists/217121-joe-satriani': {'sentiment': 'pos',
#   'z-score': 0.9122964836020417},
#  'https://www.songkick.com/artists/20890-david-gilmour': {'sentiment': 'pos',
#   'z-score': -0.12046516119718535},
#  'https://www.songkick.com/artists/211161-chris-lake': {'sentiment': 'pos',
#   'z-score': -0.4198163625882654},
#  'https://www.songkick.com/artists/127809-eddie-money': {'sentiment': 'pos',
#   'z-score': 0.5231399217936372},
#  'https://www.songkick.com/artists/445316-architecture-in-helsinki': {'sentiment': 'pos',
#   'z-score': -1.40767532717883},
#  'https://www.songkick.com/artists/267703-squeeze': {'sentiment': 'pos',
#   'z-score': 0.388431881167651},
#  'https://www.songkick.com/artists/16773-enter-shikari': {'sentiment': 'pos',
#   'z-score': -0.12046516119718535},
#  'https://www.songkick.com/artists/2250351-kill-the-noise': {'sentiment': 'pos',
#   'z-score': -0.5395568431446975},
#  'https://www.songkick.com/artists/5518983-becky-hill': {'sentiment': 'pos',
#   'z-score': 0.5830101620718533},
#  'https://www.songkick.com/artists/301301-collie-buddz': {'sentiment': 'pos',
#   'z-score': 1.017069404088919},
#  'https://www.songkick.com/artists/534301-grace-potter': {'sentiment': 'pos',
#   'z-score': 0.6129452822109613},
#  'https://www.songkick.com/artists/218998-trentemoller': {'sentiment': 'pos',
#   'z-score': 0.9871342839498111},
#  'https://www.songkick.com/artists/2393580-villagers': {'sentiment': 'pos',
#   'z-score': 0.22378872040255715},
#  'https://www.songkick.com/artists/76160-howard-shore': {'sentiment': 'pos',
#   'z-score': -1.2430321664137358},
#  ...}

# %%
pos_z_scores = [z_score_sentiments[key]["z-score"] for key in z_score_sentiments if z_score_sentiments[key]["sentiment"] == "pos"]
pos_counts = [len(artist_reivews[key]["text"]) for key in z_score_sentiments if z_score_sentiments[key]["sentiment"] == "pos"]

# %%
import scipy

# %%
scipy.stats.pearsonr(pos_z_scores, pos_counts)
# Out:
# (0.13307577359012054, 8.782759864173692e-21)

# %%
scipy.stats.spearmanr(pos_z_scores, pos_counts)
# Out:
# SpearmanrResult(correlation=0.22934641746320308, pvalue=1.9240549498224333e-59)

# %%
neg_z_scores = [z_score_sentiments[key]["z-score"] for key in z_score_sentiments if z_score_sentiments[key]["sentiment"] == "neg"]
neg_counts = [len(artist_reivews[key]["text"]) for key in z_score_sentiments if z_score_sentiments[key]["sentiment"] == "neg"]

# %%
scipy.stats.pearsonr(neg_z_scores, neg_counts)
# Out:
# (-0.011353180119608487, 0.9302116607255821)

# %%
scipy.stats.spearmanr(neg_z_scores, neg_counts)
# Out:
# SpearmanrResult(correlation=-0.31392845122147806, pvalue=0.012964821412427309)

# %%
len(neg_z_scores) + len(pos_z_scores) - len(z_score_sentiments)
# Out:
# -14

# %%
import pickle
with open("nlp_data/text_data.p", "rb") as f:
    data = pickle.load(f)

# %%
lengths = [len(row) for row in data]

# %%
sum(lengths) / len(lengths)
# Out:
# 4786.734258700462

# %%
max(lengths)
# Out:
# 40389

# %%
import numpy as np

# %%
def print_percentiles(percentiles, data):
    for per in percentiles:
        print("{} {}".format(per, np.percentile(data, per)))

# %%
print_percentiles([1,3,5,10,20,25,40,50,60,75,80,85,90,95,98,99], lengths)
# Out:
# 1 189.7
# 3 309.19999999999993
# 5 557.0
# 10 1053.0
# 20 1358.0
# 25 1564.5
# 40 2523.0
# 50 3292.0
# 60 4250.0
# 75 6541.5
# 80 7822.0
# 85 8960.5
# 90 10775.0
# 95 13740.5
# 98 17714.800000000003
# 99 20454.500000000004
