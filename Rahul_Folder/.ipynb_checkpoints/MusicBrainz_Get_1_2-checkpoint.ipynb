# %%
import jsonlines
import requests
import csv
from bs4 import BeautifulSoup
import pandas as pd
import tqdm
import random
import time
import pickle
import re

# %%
with open("songkick_names_part1_1.p", "rb") as f:
    part_1_1 = pickle.load(f)

# %%
def get_text(html_object):
    if "text" in html_object:
        return html_object["text"].strip()
    else:
        return html_object.get_text().strip()

def get_link(html_object):
    if "href" in html_object.attrs:
        return html_object.attrs["href"]
    return ""

def clean_name_of_footnote(text):
    return re.sub('\[\d+\]', '', text)

# %%
search_query = """
https://musicbrainz.org/ws/2/artist?fmt=json&query=ARTIST_NAME
"""

single_query = """
https://musicbrainz.org/ws/2/release?fmt=json&artist=ARTIST_ID&type=single&limit=100&offset=OFFSET
"""

album_query = """
https://musicbrainz.org/ws/2/release?fmt=json&artist=ARTIST_ID&type=album&limit=100&offset=OFFSET
"""

# %%
single_query
# Out:
# '\nhttps://musicbrainz.org/ws/2/release?fmt=json&artist=ARTIST_ID&type=single&limit=100&offset=OFFSET\n'

# %%
dictionaries = []
s = requests.Session()
a = requests.adapters.HTTPAdapter(max_retries=5)
s.mount('http://', a)
s.mount('https://', a)
s.headers = {'User-Agent': 'LiveMusique/1.0.0 ( https://github.com/rahul-khanna )'}

for i, name_url in enumerate(tqdm.tqdm(part_1_1)):
    if i % 100 == 0 and i > 0:
        sleep_seconds = random.randint(1, 20)
        print("Sleeping for {}".format(sleep_seconds))
        time.sleep(sleep_seconds)
        print("done sleeping")

    name = name_url[0]
    url = name_url[1]
    dict_repr = {"name" : name, "songkick_url" : url}
    updated_search_url = search_query.replace("ARTIST_NAME", name)
    x = s.get(updated_search_url, timeout=(3.05, 18.05))
    possible_results = x.json()["artists"]
    artist_id = ""
    artist_class = ""
    for result in possible_results:
        type_of_entity = result["type"]
        if type_of_entity == "Person":
            artist_id = result["id"]
            artist_class = result["gender"]
            break
        elif type_of_entity == "Group":
            artist_id = result["id"]
            artist_class = "group"
            break

    if len(artist_id) > 0:
        dict_repr["mb_id"] = artist_id
        dict_repr["mb_class"] = artist_class
        
        offset = 0
        cont = True
        updated_single_query = single_query.replace("ARTIST_ID", artist_id)
        artist_singles = []
        while cont:
            time.sleep(4)
            updated_single_query_offset = updated_single_query.replace("OFFSET", str(offset))
            y = s.get(updated_single_query_offset, timeout=(3.05, 18.05))
            singles = y.json()["releases"]
            if len(singles):
                for single in singles:
                    single_facts = {"title" : single["title"], "id" : single["id"]}
                    if "date" in single:
                        single_facts["date"] = single["date"]
                    artist_singles.append(single_facts)
                offset = offset + 100
            else:
                cont = False
        
        if len(artist_singles):
            dict_repr["singles"] = artist_singles
        
        offset = 0
        cont = True
        updated_album_query = album_query.replace("ARTIST_ID", artist_id)
        artist_albums = []
        while cont:
            time.sleep(4)
            updated_album_query_offset = updated_album_query.replace("OFFSET", str(offset))
            y = s.get(updated_album_query_offset, timeout=(3.05, 18.05))
            albums = y.json()["releases"]
            if len(albums):
                for album in albums:
                    album_facts = {"title" : album["title"], "id" : album["id"]}
                    if "date" in album:
                        album_facts["date"] = album["date"]
                    artist_albums.append(album_facts)
                offset = offset + 100
            else:
                cont = False
        
        if len(artist_albums):
            dict_repr["albums"] = artist_albums
        
    dictionaries.append(dict_repr)
# Out:
#   0%|          | 0/1396 [00:00<?, ?it/s]

# %%
dictionaries[6]
# Out:
# {'name': 'Martina McBride',
#  'songkick_url': 'https://www.songkick.com/artists/402995-martina-mcbride',
#  'mb_id': 'b0a55bd8-60c7-45c1-b78e-f20e4c8adba1',
#  'mb_class': 'female',
#  'singles': [{'title': 'Care',
#    'id': '07b20c23-cefa-46c3-b02f-0de72fb9f9d3',
#    'date': '2012'},
#   {'title': 'A Broken Wing / Valentine',
#    'id': '5e258774-0522-4281-a4e5-7fb54d3290d4',
#    'date': '1997'},
#   {'title': 'Every Single Night',
#    'id': '9487a3f2-200f-4c07-92e2-2fb9dda5afb5',
#    'date': '2013-08-12'},
#   {'title': 'Grandview',
#    'id': 'dd4b1f74-ac8f-44dd-b915-a6a80ae635b6',
#    'date': '2017-02-24'},
#   {'title': 'Ask The Boy',
#    'id': 'eb509b86-d4aa-4897-b53c-92a9856afed8',
#    'date': '2012-07-03'},
#   {'title': 'Girls Like Me',
#    'id': 'f2645713-2db7-4698-8dc0-090f5f642593',
#    'date': '2020-05-04'}],
#  'albums': [{'title': 'The Time Has Come',
#    'id': '038ad166-b68a-4ae1-8197-03887a46bb15',
#    'date': '2020-05-04'},
#   {'title': 'Timeless',
#    'id': '046dc3cb-8a49-4b4b-a890-8de16055eaf4',
#    'date': '2020-05-04'},
#   {'title': 'The Way That I Am',
#    'id': '04b56b33-9dc4-4cb6-90db-a7717f5d3cda',
#    'date': '2020-05-04'},
#   {'title': 'Everlasting',
#    'id': '183c5cae-8681-4f6d-9f0d-e86e476e26a8',
#    'date': '2020-05-04'},
#   {'title': 'The Classic Christmas Album',
#    'id': '19c883b0-afc9-40d9-9cc5-516b13c07fa9',
#    'date': '2020-05-04'},
#   {'title': 'Emotion',
#    'id': '1d845523-a674-406a-a93d-2b66c1329169',
#    'date': '2020-05-04'},
#   {'title': 'Timeless',
#    'id': '22954f31-d1db-460e-bf06-fe21de68f913',
#    'date': '2020-05-04'},
#   {'title': 'Greatest Hits',
#    'id': '2709c338-889d-411d-bb59-b97a3241d766',
#    'date': '2020-05-04'},
#   {'title': 'Eleven',
#    'id': '2ce2ea01-22ca-4846-986b-b168c8985fe1',
#    'date': '2020-05-04'},
#   {'title': 'Evolution',
#    'id': '2d28e31a-a0b2-41c7-a01d-139701bf4d21',
#    'date': '2020-05-04'},
#   {'title': 'The Way That I Am', 'id': '3633bd40-abf8-4b7a-bfd5-c16d2b7b9ee3'},
#   {'title': 'Martina',
#    'id': '37bc73ef-6f49-485c-9363-0e8c86680b1a',
#    'date': '2020-05-04'},
#   {'title': 'The Time Has Come',
#    'id': '404904be-ad43-4756-8deb-61370fed75ba',
#    'date': '2020-05-04'},
#   {'title': 'White Christmas',
#    'id': '426f99c3-855b-4a39-b164-674dcba33020',
#    'date': '2020-05-04'},
#   {'title': 'Original Album Classics',
#    'id': '4835ff37-c75b-4647-aa2f-0274047969fc',
#    'date': '2020-05-04'},
#   {'title': 'Eleven',
#    'id': '5daa8e7f-4cae-424a-8c5b-865849ffdd93',
#    'date': '2020-05-04'},
#   {'title': 'The Essential Martina McBride',
#    'id': '69d49b8f-a6ef-4845-9269-17cde396fb9b',
#    'date': '2020-05-04'},
#   {'title': 'Triple Feature',
#    'id': '6f31f4e9-b0ae-466f-9e0a-44a8ed6797ff',
#    'date': '2020-05-04'},
#   {'title': 'Everlasting',
#    'id': '730ea7e2-6616-4cd3-abc7-bb7395d7fc33',
#    'date': '2020-05-04'},
#   {'title': 'Waking Up Laughing',
#    'id': '753a59e5-a7a8-4f11-82ef-b56d6c8b874d',
#    'date': '2020-05-04'},
#   {'title': 'Playlist: The Very Best of Martina McBride',
#    'id': '774df0f4-22b0-4612-91f3-42ed75ed5083',
#    'date': '2020-05-04'},
#   {'title': 'My Heart',
#    'id': '78a30edc-749e-41d6-85e9-5927afc8759a',
#    'date': '2020-05-04'},
#   {'title': '2000-06-30: Fox Theater, Atlanta, GA, USA',
#    'id': '7934fe8c-d6b0-46d9-829d-fdf1d5084f9b'},
#   {'title': 'Original Album Classics',
#    'id': '7c4cd533-dfe2-4b18-bee5-3d37640940cf',
#    'date': '2020-05-04'},
#   {'title': 'Evolution',
#    'id': '8463431c-079b-4486-933f-c63baebff26e',
#    'date': '2020-05-04'},
#   {'title': 'Wild Angels',
#    'id': '8484e5b1-b88f-4ca9-83ec-f466d7982104',
#    'date': '2020-05-04'},
#   {'title': 'Original Album Classics',
#    'id': '85844f1e-847f-49f2-be17-b885365f560f',
#    'date': '2020-05-04'},
#   {'title': 'My Heart',
#    'id': '8943e7c1-f4b1-4e1c-b1ac-1d98c33752a0',
#    'date': '2020-05-04'},
#   {'title': 'The Way That I Am',
#    'id': '8ec1247d-b5a8-4a7e-8077-e3acb7a2d223',
#    'date': '2020-05-04'},
#   {'title': 'White Christmas',
#    'id': '920274cb-3b74-463c-92a9-882f9e3c0f46',
#    'date': '2020-05-04'},
#   {'title': 'Shine',
#    'id': '935829bc-5a88-4f92-9aaf-ba6eae9ef731',
#    'date': '2020-05-04'},
#   {'title': 'Timeless',
#    'id': '9fa2a645-25ff-47e4-8ed3-aa51794d7db6',
#    'date': '2020-05-04'},
#   {'title': 'Waking Up Laughing',
#    'id': 'a0536b2e-99c7-40ba-9a46-444d5050ecdb',
#    'date': '2020-05-04'},
#   {'title': 'Hits and More',
#    'id': 'aad5e15a-139a-4a23-8da0-8db428d5a621',
#    'date': '2020-05-04'},
#   {'title': 'Eleven',
#    'id': 'ab816ea9-49c4-42ce-a24e-fc7f51f085ba',
#    'date': '2020-05-04'},
#   {'title': 'Martina',
#    'id': 'ad499423-3103-4add-9c4b-1cadc4b2e377',
#    'date': '2020-05-04'},
#   {'title': 'Reckless',
#    'id': 'ae0ee20a-9da8-48a3-a85a-c31dc0fa7e9b',
#    'date': '2020-05-04'},
#   {'title': 'Emotion',
#    'id': 'be071c9f-c3b7-4017-936a-cfc1b31a071d',
#    'date': '2020-05-04'},
#   {'title': 'Emotion',
#    'id': 'c31e599f-7a22-4eae-9593-6b090982a09f',
#    'date': '2020-05-04'},
#   {'title': 'White Christmas',
#    'id': 'c90e1e10-73d9-4afb-81f4-0e8e71f7db4b',
#    'date': '2020-05-04'},
#   {'title': 'Greatest Hits: Video Collection',
#    'id': 'cdb8b481-cf3c-4b54-a38a-011ec786f7f3',
#    'date': '2020-05-04'},
#   {'title': 'Live in Concert',
#    'id': 'd15e313d-c4fa-4715-9c68-8b00d613e1d0',
#    'date': '2020-05-04'},
#   {'title': 'Reckless',
#    'id': 'd19d8ea1-58a0-4cf7-babf-a30c318c9184',
#    'date': '2020-05-04'},
#   {'title': 'Greatest Hits',
#    'id': 'dff1ac29-9f0c-4a8c-911d-2a19582744f5',
#    'date': '2020-05-04'},
#   {'title': 'Martina',
#    'id': 'e1475e84-0ace-4964-bcfa-19bc313e6a78',
#    'date': '2020-05-04'},
#   {'title': 'White Christmas',
#    'id': 'e5546354-1efa-46fc-a5b8-9b97552e9c48',
#    'date': '2020-05-04'},
#   {'title': "It's the Holiday Season",
#    'id': 'eda78983-7e72-40a0-9679-f6e37b245895',
#    'date': '2020-05-04'},
#   {'title': 'Emotion',
#    'id': 'ff9ff83c-bb0c-4040-bf98-592f7e9c26c1',
#    'date': '2020-05-04'}]}
